# %%
"""
Controller module for the Vehicle Routing Problem.
Orchestrates the entire process of solving the VRP.
"""

import pandas as pd
from datetime import datetime
import os

from vehi_rout.config import (
    TOTAL_DAYS,
    DISTANCE_BASE_PENALTY,
    TIME_BASE_PENALTY
)
from vehi_rout.utils.data_utils import (
    load_matrix_df,
    load_df,
    get_demand_df,
    update_demand_dic
)
from vehi_rout.utils.helper_utils import (
    get_penalty_list,
    get_values_not_in_second_list
)
from vehi_rout.utils.route_utils import sort_nodes_by_distance
from vehi_rout.utils.visualization import (
    visualize_routes_per_vehicle,
    print_route_summary,
    save_route_details_to_csv
)
from vehi_rout.solver.vrp_solver import (
    solve_vrp_for_day,
    solve_multi_day_vrp
)

class VRPController:
    """Controller class for the Vehicle Routing Problem."""

    def __init__(self, use_distance=True):
        """
        Initialize the VRP controller.

        Args:
            use_distance: Boolean indicating whether to use distance or time
        """
        self.use_distance = use_distance
        self.base_penalty = DISTANCE_BASE_PENALTY if use_distance else TIME_BASE_PENALTY
        self.demand_df = None
        self.master_mat_df = None
        self.master_gps_df = None
        self.demand_dict = None
        self.penalty_list = None

    def load_data(self, demand_path, matrix_path, gps_path):
        """
        Load data from files.

        Args:
            demand_path: Path to the demand file
            matrix_path: Path to the distance/time matrix file
            gps_path: Path to the GPS coordinates file
        """
        # Load demand data
        self.demand_df = get_demand_df(today_path=demand_path)

        # Convert CODE to string if it's numeric
        if self.demand_df['CODE'].dtype in ['float', 'int', 'int64']:
            self.demand_df['CODE'] = self.demand_df['CODE'].astype(int)
            self.demand_df['CODE'] = self.demand_df['CODE'].astype(str)
            print('Converting CODE to string')

        # Load distance/time matrix
        self.master_mat_df = load_matrix_df(path=matrix_path)

        # Load GPS coordinates
        self.master_gps_df = load_df(path=gps_path)

        # Add depot (SMAK_KADAWATHA) to the GPS data
        SMAK_KADAWATHA = (7.0038321, 79.9394804)
        smak_data = {
            "CODE": '0',
            "LOCATION": "SMAK",
            "ADDRESS": "Smak, Kadawatha, Western Province, Sri Lanka",
            "LATITUDE": SMAK_KADAWATHA[0],
            "LONGITUDE": SMAK_KADAWATHA[1]
        }

        # Always ensure the depot is in the master_gps_df
        import pandas as pd

        # Remove any existing depot entries
        if '0' in self.master_gps_df['CODE'].values:
            self.master_gps_df = self.master_gps_df[self.master_gps_df['CODE'] != '0']

        # Add depot to the GPS data at the beginning
        self.master_gps_df = pd.concat(
            [
                pd.DataFrame([smak_data]),
                self.master_gps_df
            ],
            ignore_index=True
        )
        print("Added depot (SMAK_KADAWATHA) to GPS data")

        # Create demand dictionary
        self.demand_dict = update_demand_dic(self.demand_df)

        # Calculate penalties
        today = datetime.now().strftime('%Y-%m-%d')
        self.penalty_list = get_penalty_list(self.demand_dict, self.base_penalty, TOTAL_DAYS, today)

        print(f"Loaded {len(self.demand_df)} demand records")
        print(f"Loaded {len(self.master_mat_df)} locations in distance/time matrix")
        print(f"Loaded {len(self.master_gps_df)} locations with GPS coordinates")


    def solve_single_day(self, day=0, max_nodes=None, save_visualization=False):
        """
        Solve the VRP for a single day.

        Args:
            day: Day index (0-based)
            max_nodes: Maximum number of nodes to visit
            save_visualization: Boolean indicating whether to save visualization

        Returns:
            visited_nodes: Set of visited node indices
            route_dict: Dictionary containing route information for each vehicle
        """
        if self.demand_df is None or self.master_mat_df is None or self.master_gps_df is None:
            raise ValueError("Data not loaded. Call load_data() first.")

        # Get nodes to visit
        all_nodes = list(range(1, len(self.master_mat_df)))

        # Sort nodes by distance from depot
        sorted_nodes = sort_nodes_by_distance(self.master_mat_df.values)

        # Limit the number of nodes if specified
        if max_nodes is not None and max_nodes < len(sorted_nodes):
            nodes_to_visit = sorted(sorted_nodes[:max_nodes])
        else:
            nodes_to_visit = all_nodes

        # Solve VRP
        visited_nodes, route_dict = solve_vrp_for_day(
            self.master_mat_df,
            nodes_to_visit,
            day,
            self.demand_dict,
            self.penalty_list,
            self.use_distance
        )

        # Create output directories
        self._create_output_directories()

        # Print and save summary
        summary_file = f"output/summaries/day_{day + 1}_summary.txt"
        print_route_summary(route_dict, self.use_distance, file_path=summary_file)

        # Save detailed route information to CSV
        csv_file = f"output/csv/day_{day + 1}_routes.csv"
        save_route_details_to_csv(route_dict, day, self.use_distance, file_path=csv_file)

        # Visualize routes
        if save_visualization:
            maps_dict = visualize_routes_per_vehicle(
                self.master_gps_df,
                route_dict,
                day,
                use_distance=self.use_distance
            )

            # Save maps to files
            os.makedirs("output/maps", exist_ok=True)
            for vehicle_id, m in maps_dict.items():
                m.save(f"output/maps/day_{day + 1}_vehicle_{vehicle_id}_route.html")

        # Save unvisited nodes for next-day processing
        all_po_nodes = self.get_po_node_indices()
        unvisited = all_po_nodes - visited_nodes
        self._save_unvisited_nodes_to_csv(unvisited)

        return visited_nodes, route_dict

    def solve_multi_day(self, total_days=None, max_nodes=None, save_visualization=False):
        """
        Solve the VRP for multiple days.

        Args:
            total_days: Number of days to plan
            max_nodes: Maximum number of nodes to visit per day
            save_visualization: Boolean indicating whether to save visualization

        Returns:
            all_visited_nodes: List of sets of visited node indices for each day
            all_route_dicts: List of dictionaries containing route information for each day
        """
        if self.demand_df is None or self.master_mat_df is None or self.master_gps_df is None:
            raise ValueError("Data not loaded. Call load_data() first.")

        # Use default total days if not specified
        if total_days is None:
            total_days = TOTAL_DAYS

        # Solve multi-day VRP
        all_visited_nodes, all_route_dicts = solve_multi_day_vrp(
            self.master_mat_df,
            self.demand_dict,
            total_days,
            self.base_penalty,
            self.use_distance,
            current_date=None,
            max_nodes_per_day=max_nodes
        )

        # Create output directories
        self._create_output_directories()

        # Create a combined CSV for all days
        combined_csv_path = f"output/csv/all_days_routes.csv"
        import csv
        with open(combined_csv_path, 'w', newline='') as csvfile:
            metric_name = "distance" if self.use_distance else "time"
            unit = "km" if self.use_distance else "mins"
            fieldnames = ['Day', 'Vehicle', 'Stops', f'{metric_name.capitalize()} ({unit})',
                         f'Max {metric_name.capitalize()} ({unit})', 'Within Limit', 'Route']
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()

        # Process each day
        for day, route_dict in enumerate(all_route_dicts):
            print(f"\n=== Day {day + 1} ===")

            # Print and save summary
            summary_file = f"output/summaries/day_{day + 1}_summary.txt"
            print_route_summary(route_dict, self.use_distance, file_path=summary_file)

            # Save detailed route information to CSV
            csv_file = f"output/csv/day_{day + 1}_routes.csv"
            save_route_details_to_csv(route_dict, day, self.use_distance, file_path=csv_file)

            # Append to combined CSV
            self._append_to_combined_csv(route_dict, day, combined_csv_path)

            # Visualize routes
            if save_visualization:
                maps_dict = visualize_routes_per_vehicle(
                    self.master_gps_df,
                    route_dict,
                    day,
                    use_distance=self.use_distance
                )

                # Save maps to files
                for vehicle_id, m in maps_dict.items():
                    m.save(f"output/maps/day_{day + 1}_vehicle_{vehicle_id}_route.html")

        # Create a multi-day summary
        self._save_multi_day_summary(all_route_dicts, all_visited_nodes)

        return all_visited_nodes, all_route_dicts

    def _append_to_combined_csv(self, route_dict, day, file_path):
        """
        Append route information to a combined CSV file.

        Args:
            route_dict: Dictionary containing route information for each vehicle
            day: Day index (0-based)
            file_path: Path to the CSV file
        """
        import csv

        metric_name = "distance" if self.use_distance else "time"
        unit = "km" if self.use_distance else "mins"

        with open(file_path, 'a', newline='') as csvfile:
            fieldnames = ['Day', 'Vehicle', 'Stops', f'{metric_name.capitalize()} ({unit})',
                         f'Max {metric_name.capitalize()} ({unit})', 'Within Limit', 'Route']
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

            for vehicle_id, route_info in route_dict.items():
                route_metric = route_info.get(f"route_{metric_name}", 0)
                num_visits = route_info.get("num_visits", 0)
                max_metric = route_info.get(f"max_{metric_name}_limit", 0)
                within_limit = route_info.get("within_limit", False)
                route_nodes = ' -> '.join(map(str, route_info.get("route_nodes", [])))

                writer.writerow({
                    'Day': day + 1,
                    'Vehicle': vehicle_id,
                    'Stops': num_visits,
                    f'{metric_name.capitalize()} ({unit})': route_metric,
                    f'Max {metric_name.capitalize()} ({unit})': max_metric,
                    'Within Limit': 'Yes' if within_limit else 'No',
                    'Route': route_nodes
                })

    def _save_multi_day_summary(self, all_route_dicts, all_visited_nodes):
        """
        Save a summary of the multi-day routing and create a next-day demand file.

        Args:
            all_route_dicts: List of dictionaries containing route information for each day
            all_visited_nodes: List of sets of visited node indices for each day
        """
        metric_name = "distance" if self.use_distance else "time"
        unit = "km" if self.use_distance else "mins"

        # Calculate total metrics
        total_metric = 0
        total_visits = 0

        for route_dict in all_route_dicts:
            for vehicle_id, route_info in route_dict.items():
                total_metric += route_info.get(f"route_{metric_name}", 0)
                total_visits += route_info.get("num_visits", 0)

        # Calculate visited and unvisited nodes
        all_visited = set()
        for visited in all_visited_nodes:
            all_visited.update(visited)

        # Get all nodes from the demand data (PO file) instead of master data
        all_po_nodes = self.get_po_node_indices()
        unvisited = all_po_nodes - all_visited

        # Create summary lines
        summary_lines = []
        summary_lines.append(f"Multi-Day Routing Summary")
        summary_lines.append(f"-" * 50)
        summary_lines.append(f"Total days: {len(all_route_dicts)}")
        summary_lines.append(f"Total vehicles: {len(all_route_dicts[0]) if all_route_dicts else 0}")
        summary_lines.append(f"Total stops: {total_visits}")
        summary_lines.append(f"Total {metric_name}: {total_metric} {unit}")
        summary_lines.append(f"Total nodes visited: {len(all_visited)}")
        summary_lines.append(f"Total nodes unvisited: {len(unvisited)}")
        summary_lines.append(f"-" * 50)

        # Save to file
        summary_file = "output/summaries/multi_day_summary.txt"
        with open(summary_file, 'w') as f:
            for line in summary_lines:
                f.write(line + '\n')

            # Add unvisited nodes if any
            if unvisited:
                f.write(f"\nUnvisited nodes:\n")
                unvisited_codes = [self.master_mat_df.index[i] for i in unvisited if i < len(self.master_mat_df.index)]
                for i, code in enumerate(unvisited_codes):
                    f.write(f"{code}")
                    if (i + 1) % 10 == 0:  # 10 codes per line
                        f.write("\n")
                    else:
                        f.write(", ")

        print(f"Multi-day summary saved to {summary_file}")

        # Save unvisited nodes to a CSV file for next-day processing
        self._save_unvisited_nodes_to_csv(unvisited)

    def _create_output_directories(self):
        """
        Create output directories for saving results.
        """
        os.makedirs("output", exist_ok=True)
        os.makedirs("output/summaries", exist_ok=True)
        os.makedirs("output/csv", exist_ok=True)
        os.makedirs("output/maps", exist_ok=True)

    def get_po_node_indices(self):
        """
        Get the indices of nodes in the purchase order (PO) file.

        Returns:
            set: Set of node indices from the PO file
        """
        po_node_indices = []
        for code in self.demand_dict['key']:
            if code in self.master_mat_df.index:
                idx = self.master_mat_df.index.get_loc(code)
                po_node_indices.append(str(code))

        return set(po_node_indices)

    def _save_unvisited_nodes_to_csv(self, unvisited):
        """
        Save unvisited nodes to a CSV file for next-day processing.

        Args:
            unvisited: Set of unvisited node indices
        """
        import pandas as pd

        # Get the unvisited node codes
        # unvisited_codes = [self.master_mat_df.index[i] for i in unvisited if i < len(self.master_mat_df.index)]
        unvisited_codes = list(unvisited)

        if not unvisited_codes:
            print("No unvisited nodes to save for next day.")
            return

        # Create a DataFrame with the unvisited nodes
        next_day_df = pd.DataFrame()

        # Filter the demand DataFrame to include only unvisited nodes
        if self.demand_df is not None:
            # Convert unvisited_codes to the same type as demand_df['CODE']
            unvisited_codes_set = set(str(code) for code in unvisited_codes)
            next_day_df = self.demand_df[self.demand_df['CODE'].astype(str).isin(unvisited_codes_set)].copy()

        if next_day_df.empty:
            print("Warning: Could not find demand data for unvisited nodes.")
            # Create a simple DataFrame with just the codes
            next_day_df = pd.DataFrame({'CODE': unvisited_codes})
            
        if 'DEMAND' in next_day_df.columns:
            next_day_df.drop(columns=['DEMAND'], inplace=True)

        # Save to CSV
        next_day_file = "output/csv/next_day_demand.csv"
        next_day_df.to_csv(next_day_file, index=False)
        print(f"Saved {len(next_day_df)} unvisited nodes to {next_day_file} for next-day processing.")

    def update_vehicle_config(self, num_vehicles, max_visits, max_distance):
        """
        Update the vehicle configuration parameters.

        Args:
            num_vehicles: Number of vehicles
            max_visits: List of maximum visits per vehicle
            max_distance: List of maximum distance per vehicle
        """
        # Validate inputs
        if len(max_visits) != num_vehicles or len(max_distance) != num_vehicles:
            raise ValueError("Length of max_visits and max_distance must match num_vehicles")

        # Create new lists with the correct length
        new_max_visits = max_visits.copy()
        new_max_distance = max_distance.copy()

        # Update the configuration in the config module
        import vehi_rout.config as config
        config.MAX_VISITS_PER_VEHICLE = new_max_visits
        config.MAX_DISTANCE_PER_VEHICLE = new_max_distance

        print(f"Updated vehicle configuration:")
        print(f"Number of vehicles: {num_vehicles}")
        print(f"Max visits per vehicle: {new_max_visits}")
        print(f"Max distance per vehicle: {new_max_distance}")
# Out:
# No cache file found at ../data/csv/route_cache.csv, starting fresh
# load c:\Users\HP\Desktop\E-Vision-Projects\Vehicle_Routing\venv\Lib\site-packages\ortools\.libs\zlib1.dll...
# load c:\Users\HP\Desktop\E-Vision-Projects\Vehicle_Routing\venv\Lib\site-packages\ortools\.libs\abseil_dll.dll...
# load c:\Users\HP\Desktop\E-Vision-Projects\Vehicle_Routing\venv\Lib\site-packages\ortools\.libs\utf8_validity.dll...
# load c:\Users\HP\Desktop\E-Vision-Projects\Vehicle_Routing\venv\Lib\site-packages\ortools\.libs\re2.dll...
# load c:\Users\HP\Desktop\E-Vision-Projects\Vehicle_Routing\venv\Lib\site-packages\ortools\.libs\libprotobuf.dll...
# load c:\Users\HP\Desktop\E-Vision-Projects\Vehicle_Routing\venv\Lib\site-packages\ortools\.libs\highs.dll...
# load c:\Users\HP\Desktop\E-Vision-Projects\Vehicle_Routing\venv\Lib\site-packages\ortools\.libs\ortools.dll...

# %%
controller = VRPController()

# %%
matrix_path = '../data/master/osrm_distance_matrix.csv'
gps_path = '../data/master/master_gps.csv'
demand_path = 'data/day-01.csv'  #'output/csv/next_day_demand.csv'

controller.load_data(
    demand_path=demand_path,
    matrix_path=matrix_path,
    gps_path=gps_path
)

num_vehicles=8
max_visits = [15, 15, 15, 15, 15, 15, 15, 15]
max_distance =[300, 300, 300, 300, 300, 300, 300, 300]


controller.update_vehicle_config(num_vehicles, max_visits, max_distance)

visited_nodes, route_dict =controller.solve_single_day(save_visualization=True)
# Out:
# Added depot (SMAK_KADAWATHA) to GPS data
# Loaded 454 demand records
# Loaded 651 locations in distance/time matrix
# Loaded 651 locations with GPS coordinates
# Updated vehicle configuration:
# Number of vehicles: 8
# Max visits per vehicle: [15, 15, 15, 15, 15, 15, 15, 15]
# Max distance per vehicle: [300, 300, 300, 300, 300, 300, 300, 300]
# Max Distance: [300, 300, 300, 300, 300, 300, 300, 300]
#
# Day 1 Routes (Penalty per unvisited demand unit: 100000 km):
# Route for vehicle 0:
#  0 -> 1292 -> 1433 -> 1145 -> 14003 -> 1303 -> SCUP -> 1017 -> 5 -> 1661 -> 1676 -> 14011 -> 1419 -> 1107 -> 1888 -> SCTB -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 1:
#  0 -> 22 -> 116 -> SCBT -> SCTG -> 14012 -> SCPK -> SCHD -> SCTL -> 156 -> SGGP -> 24 -> SGMP -> 114 -> SGTI -> SGYK -> 0
# Distance of the route: 75 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 2:
#  0 -> 1728 -> 1497 -> 1872 -> 1471 -> 1320 -> SCCR -> SCSJ -> SCRJ -> SCNW -> 14008 -> 1761 -> 1323 -> 1859 -> 1446 -> 1364 -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 3:
#  0 -> 14013 -> 171 -> 1137 -> SCMY -> 1555 -> SCK7 -> 1108 -> SCKE -> 1818 -> 1005 -> 1672 -> 1902 -> 1826 -> 1608 -> 1105 -> 0
# Distance of the route: 47 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 4:
#  0 -> SGSM -> SCMU -> 172 -> 1745 -> SCGT -> SCWP -> 1614 -> 1896 -> 1776 -> 1301 -> 1746 -> 1759 -> SCSL -> 1545 -> SGKY -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 5:
#  0 -> SGJW -> SGNO -> SGJA -> 1084 -> SGKC -> SGSE -> 128 -> SGNK -> 26 -> SGND -> 14007 -> SGN2 -> 123 -> SGMI -> SGGE -> 0
# Distance of the route: 77 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 6:
#  0 -> SGMQ -> 1355 -> 1548 -> 1549 -> SCAK -> SCVJ -> SCAR -> SCPT -> SCTH -> SCBI -> SLMN -> 110 -> 14010 -> 1678 -> SCKX -> 0
# Distance of the route: 50 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 7:
#  0 -> SGEM -> SGKG -> SGKB -> 14 -> SGTY -> SGKR -> SGWA -> 14015 -> 117 -> 3 -> SGMH -> SGRA -> 150 -> SGEL -> SGK5 -> 0
# Distance of the route: 35 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Maximum route distance for Day 1: 77 km
# Route Summary:
#     Vehicle    Stops      Distance        Within Limit
# -------------------------------------------------------
#     0          15         36         km   Yes
#     1          15         75         km   Yes
#     2          15         36         km   Yes
#     3          15         47         km   Yes
#     4          15         36         km   Yes
#     5          15         77         km   Yes
#     6          15         50         km   Yes
#     7          15         35         km   Yes
# -------------------------------------------------------
#     Total      120        392        km
# Summary saved to output/summaries/day_1_summary.txt
# Route details saved to output/csv/day_1_routes.csv
# Processing route for vehicle 0: ['0', '1292', '1433', '1145', '14003', '1303', 'SCUP', '1017', '5', '1661', '1676', '14011', '1419', '1107', '1888', 'SCTB', '0']
# Fetching path from 0 ((7.0038321, 79.9394804)) to 1292 ((6.9443444, 79.8670732))
# Path cached for 0 to 1292: [[7.003795, 79.939624], [7.003747, 79.939611], [7.003646, 79.939576], [7.00356, 79.939533], [7.003509, 79.939495]]... (total 416 points)
# Added path from 0 to 1292 with 416 points
# Fetching path from 1292 ((6.9443444, 79.8670732)) to 1433 ((6.9223969, 79.8659984))
# Path cached for 1292 to 1433: [[6.944493, 79.86701], [6.944428, 79.866854], [6.944395, 79.866741], [6.944386, 79.866672], [6.944396, 79.866635]]... (total 99 points)
# Added path from 1292 to 1433 with 99 points
# Fetching path from 1433 ((6.9223969, 79.8659984)) to 1145 ((6.9240228, 79.8686059))
# Path cached for 1433 to 1145: [[6.922354, 79.865843], [6.921966, 79.865953], [6.921939, 79.865803], [6.9222, 79.865745], [6.92276, 79.865567]]... (total 20 points)
# Added path from 1433 to 1145 with 20 points
# Fetching path from 1145 ((6.9240228, 79.8686059)) to 14003 ((6.9205009, 79.8658211))
# Path cached for 1145 to 14003: [[6.924024, 79.868607], [6.9239, 79.868728], [6.923804, 79.868823], [6.923333, 79.869277], [6.923266, 79.869221]]... (total 24 points)
# Added path from 1145 to 14003 with 24 points
# Fetching path from 14003 ((6.9205009, 79.8658211)) to 1303 ((6.9166038, 79.8649075))
# Path cached for 14003 to 1303: [[6.920559, 79.866059], [6.920685, 79.866028], [6.920853, 79.866012], [6.921939, 79.865803], [6.921966, 79.865953]]... (total 24 points)
# Added path from 14003 to 1303 with 24 points
# Fetching path from 1303 ((6.9166038, 79.8649075)) to SCUP ((6.9197379, 79.8589027))
# Path cached for 1303 to SCUP: [[6.916604, 79.864896], [6.916382, 79.864896], [6.916026, 79.864902], [6.915314, 79.864894], [6.914429, 79.864848]]... (total 51 points)
# Added path from 1303 to SCUP with 51 points
# Fetching path from SCUP ((6.9197379, 79.8589027)) to 1017 ((6.9202229, 79.855804))
# Path cached for SCUP to 1017: [[6.919696, 79.858987], [6.919041, 79.858658], [6.918971, 79.858655], [6.918909, 79.858721], [6.918789, 79.85897]]... (total 27 points)
# Added path from SCUP to 1017 with 27 points
# Fetching path from 1017 ((6.9202229, 79.855804)) to 5 ((6.9175873, 79.8585189))
# Path cached for 1017 to 5: [[6.920255, 79.855775], [6.920294, 79.855697], [6.919749, 79.855438], [6.91969, 79.855422], [6.919627, 79.855425]]... (total 36 points)
# Added path from 1017 to 5 with 36 points
# Fetching path from 5 ((6.9175873, 79.8585189)) to 1661 ((6.9117245, 79.8614617))
# Path cached for 5 to 1661: [[6.917532, 79.858451], [6.91768, 79.858329], [6.918015, 79.858058], [6.918164, 79.857942], [6.918181, 79.857913]]... (total 56 points)
# Added path from 5 to 1661 with 56 points
# Fetching path from 1661 ((6.9117245, 79.8614617)) to 1676 ((6.9018407, 79.8692882))
# Path cached for 1661 to 1676: [[6.911751, 79.861461], [6.911769, 79.861798], [6.911778, 79.861968], [6.911819, 79.862737], [6.91181, 79.863499]]... (total 77 points)
# Added path from 1661 to 1676 with 77 points
# Fetching path from 1676 ((6.9018407, 79.8692882)) to 14011 ((6.9009, 79.8707))
# Path cached for 1676 to 14011: [[6.90184, 79.869289], [6.901813, 79.869252], [6.901773, 79.869189], [6.901281, 79.869575], [6.90083, 79.869874]]... (total 8 points)
# Added path from 1676 to 14011 with 8 points
# Fetching path from 14011 ((6.9009, 79.8707)) to 1419 ((6.8949964, 79.8667069))
# Path cached for 14011 to 1419: [[6.901215, 79.870481], [6.901036, 79.87022], [6.900905, 79.870002], [6.90083, 79.869874], [6.901281, 79.869575]]... (total 31 points)
# Added path from 14011 to 1419 with 31 points
# Fetching path from 1419 ((6.8949964, 79.8667069)) to 1107 ((6.8936437, 79.8704269))
# Path cached for 1419 to 1107: [[6.895014, 79.866918], [6.894152, 79.866993], [6.893872, 79.867004], [6.893172, 79.866956], [6.893152, 79.866954]]... (total 26 points)
# Added path from 1419 to 1107 with 26 points
# Fetching path from 1107 ((6.8936437, 79.8704269)) to 1888 ((6.8881939, 79.8677688))
# Path cached for 1107 to 1888: [[6.893649, 79.870433], [6.893644, 79.870438], [6.893097, 79.870055], [6.893072, 79.870038], [6.892805, 79.869875]]... (total 27 points)
# Added path from 1107 to 1888 with 27 points
# Fetching path from 1888 ((6.8881939, 79.8677688)) to SCTB ((6.8936437, 79.8704269))
# Path cached for 1888 to SCTB: [[6.888217, 79.86777], [6.888199, 79.868326], [6.888188, 79.868925], [6.888896, 79.868974], [6.88928, 79.869002]]... (total 27 points)
# Added path from 1888 to SCTB with 27 points
# Fetching path from SCTB ((6.8936437, 79.8704269)) to 0 ((7.0038321, 79.9394804))
# Path cached for SCTB to 0: [[6.893649, 79.870433], [6.893644, 79.870438], [6.893912, 79.870679], [6.894035, 79.870818], [6.894223, 79.870991]]... (total 441 points)
# Added path from SCTB to 0 with 441 points
# Plotted path for vehicle 0 with 1390 coordinates
# Processing route for vehicle 1: ['0', '22', '116', 'SCBT', 'SCTG', '14012', 'SCPK', 'SCHD', 'SCTL', '156', 'SGGP', '24', 'SGMP', '114', 'SGTI', 'SGYK', '0']
# Fetching path from 0 ((7.0038321, 79.9394804)) to 22 ((6.8979941, 79.9222869))
# Path cached for 0 to 22: [[7.003795, 79.939624], [7.003747, 79.939611], [7.003646, 79.939576], [7.00356, 79.939533], [7.003509, 79.939495]]... (total 555 points)
# Added path from 0 to 22 with 555 points
# Fetching path from 22 ((6.8979941, 79.9222869)) to 116 ((6.8758648, 79.9391936))
# Path cached for 22 to 116: [[6.897995, 79.922306], [6.897937, 79.92231], [6.897753, 79.922335], [6.897489, 79.922375], [6.89739, 79.922398]]... (total 121 points)
# Added path from 22 to 116 with 121 points
# Fetching path from 116 ((6.8758648, 79.9391936)) to SCBT ((6.8756534, 79.9358023))
# Path cached for 116 to SCBT: [[6.875869, 79.939112], [6.876012, 79.93912], [6.876217, 79.939074], [6.876462, 79.938868], [6.876699, 79.938653]]... (total 29 points)
# Added path from 116 to SCBT with 29 points
# Fetching path from SCBT ((6.8756534, 79.9358023)) to SCTG ((6.8749467, 79.9364678))
# Path cached for SCBT to SCTG: [[6.875647, 79.935794], [6.875693, 79.935759], [6.875883, 79.93562], [6.876238, 79.935368], [6.876321, 79.935309]]... (total 15 points)
# Added path from SCBT to SCTG with 15 points
# Fetching path from SCTG ((6.8749467, 79.9364678)) to 14012 ((6.8758648, 79.9391936))
# Path cached for SCTG to 14012: [[6.874937, 79.936457], [6.873979, 79.937341], [6.873938, 79.937291], [6.874787, 79.93651], [6.875103, 79.936215]]... (total 27 points)
# Added path from SCTG to 14012 with 27 points
# Fetching path from 14012 ((6.8758648, 79.9391936)) to SCPK ((6.8802431, 79.9475213))
# Path cached for 14012 to SCPK: [[6.875869, 79.939112], [6.876012, 79.93912], [6.876217, 79.939074], [6.876462, 79.938868], [6.876699, 79.938653]]... (total 45 points)
# Added path from 14012 to SCPK with 45 points
# Fetching path from SCPK ((6.8802431, 79.9475213)) to SCHD ((6.8796442, 79.9458337))
# Path cached for SCPK to SCHD: [[6.880268, 79.947524], [6.880279, 79.947423], [6.880227, 79.947098], [6.880184, 79.946988], [6.879936, 79.946586]]... (total 6 points)
# Added path from SCPK to SCHD with 6 points
# Fetching path from SCHD ((6.8796442, 79.9458337)) to SCTL ((6.8802431, 79.9475213))
# Path cached for SCHD to SCTL: [[6.879656, 79.94583], [6.879936, 79.946586], [6.880184, 79.946988], [6.880227, 79.947098], [6.880279, 79.947423]]... (total 9 points)
# Added path from SCHD to SCTL with 9 points
# Fetching path from SCTL ((6.8802431, 79.9475213)) to 156 ((7.0318781, 80.0283415))
# Path cached for SCTL to 156: [[6.880268, 79.947524], [6.880279, 79.947423], [6.880296, 79.947667], [6.880286, 79.947839], [6.880302, 79.948224]]... (total 624 points)
# Added path from SCTL to 156 with 624 points
# Fetching path from 156 ((7.0318781, 80.0283415)) to SGGP ((7.0849349, 80.0087892))
# Path cached for 156 to SGGP: [[7.031908, 80.028406], [7.032103, 80.028312], [7.032455, 80.02811], [7.032746, 80.027889], [7.032955, 80.027706]]... (total 157 points)
# Added path from 156 to SGGP with 157 points
# Fetching path from SGGP ((7.0849349, 80.0087892)) to 24 ((7.0840484, 80.0098314))
# Path cached for SGGP to 24: [[7.08494, 80.008796], [7.084858, 80.008854], [7.084758, 80.00897], [7.0846, 80.009153], [7.084558, 80.009199]]... (total 10 points)
# Added path from SGGP to 24 with 10 points
# Fetching path from 24 ((7.0840484, 80.0098314)) to SGMP ((7.0754409, 80.0143367))
# Path cached for 24 to SGMP: [[7.084032, 80.009814], [7.083953, 80.009887], [7.083539, 80.010197], [7.083495, 80.010224], [7.083281, 80.010353]]... (total 32 points)
# Added path from 24 to SGMP with 32 points
# Fetching path from SGMP ((7.0754409, 80.0143367)) to 114 ((7.0864153, 80.0335107))
# Path cached for SGMP to 114: [[7.075424, 80.014305], [7.075312, 80.014365], [7.075292, 80.014378], [7.075155, 80.014467], [7.074909, 80.014636]]... (total 77 points)
# Added path from SGMP to 114 with 77 points
# Fetching path from 114 ((7.0864153, 80.0335107)) to SGTI ((7.1208728, 80.0636742))
# Path cached for 114 to SGTI: [[7.086507, 80.033323], [7.086176, 80.033159], [7.085985, 80.033455], [7.086175, 80.033685], [7.086335, 80.033892]]... (total 219 points)
# Added path from 114 to SGTI with 219 points
# Fetching path from SGTI ((7.1208728, 80.0636742)) to SGYK ((7.0824867, 80.030854))
# Path cached for SGTI to SGYK: [[7.120848, 80.06369], [7.120756, 80.063545], [7.120334, 80.062867], [7.119946, 80.062255], [7.119815, 80.062017]]... (total 210 points)
# Added path from SGTI to SGYK with 210 points
# Fetching path from SGYK ((7.0824867, 80.030854)) to 0 ((7.0038321, 79.9394804))
# Path cached for SGYK to 0: [[7.082931, 80.030399], [7.082862, 80.03033], [7.082748, 80.030209], [7.082594, 80.030045], [7.082488, 80.029933]]... (total 721 points)
# Added path from SGYK to 0 with 721 points
# Plotted path for vehicle 1 with 2857 coordinates
# Processing route for vehicle 2: ['0', '1728', '1497', '1872', '1471', '1320', 'SCCR', 'SCSJ', 'SCRJ', 'SCNW', '14008', '1761', '1323', '1859', '1446', '1364', '0']
# Fetching path from 0 ((7.0038321, 79.9394804)) to 1728 ((6.9379638, 79.878569))
# Path cached for 0 to 1728: [[7.003795, 79.939624], [7.003747, 79.939611], [7.003646, 79.939576], [7.00356, 79.939533], [7.003509, 79.939495]]... (total 423 points)
# Added path from 0 to 1728 with 423 points
# Fetching path from 1728 ((6.9379638, 79.878569)) to 1497 ((6.9352993, 79.8807831))
# Path cached for 1728 to 1497: [[6.937971, 79.878352], [6.937793, 79.878346], [6.93772, 79.878345], [6.936969, 79.87833], [6.936932, 79.878329]]... (total 28 points)
# Added path from 1728 to 1497 with 28 points
# Fetching path from 1497 ((6.9352993, 79.8807831)) to 1872 ((6.9180122, 79.885249))
# Path cached for 1497 to 1872: [[6.935278, 79.880775], [6.935331, 79.880623], [6.934889, 79.880386], [6.934849, 79.880355], [6.93482, 79.88031]]... (total 103 points)
# Added path from 1497 to 1872 with 103 points
# Fetching path from 1872 ((6.9180122, 79.885249)) to 1471 ((6.9113889, 79.8866667))
# Path cached for 1872 to 1471: [[6.91807, 79.885119], [6.917961, 79.885015], [6.917929, 79.884903], [6.917911, 79.884435], [6.91784, 79.884204]]... (total 37 points)
# Added path from 1872 to 1471 with 37 points
# Fetching path from 1471 ((6.9113889, 79.8866667)) to 1320 ((6.9065768, 79.8871277))
# Path cached for 1471 to 1320: [[6.911477, 79.886429], [6.9111, 79.886288], [6.911001, 79.88626], [6.910966, 79.887083], [6.910868, 79.887519]]... (total 23 points)
# Added path from 1471 to 1320 with 23 points
# Fetching path from 1320 ((6.9065768, 79.8871277)) to SCCR ((6.9108052, 79.8891173))
# Path cached for 1320 to SCCR: [[6.906585, 79.887101], [6.906738, 79.887144], [6.906993, 79.887215], [6.907367, 79.887296], [6.907482, 79.887316]]... (total 44 points)
# Added path from 1320 to SCCR with 44 points
# Fetching path from SCCR ((6.9108052, 79.8891173)) to SCSJ ((6.9094108, 79.8942538))
# Path cached for SCCR to SCSJ: [[6.910817, 79.889116], [6.910831, 79.889236], [6.910858, 79.889438], [6.91092, 79.889976], [6.910941, 79.890143]]... (total 31 points)
# Added path from SCCR to SCSJ with 31 points
# Fetching path from SCSJ ((6.9094108, 79.8942538)) to SCRJ ((6.9103636, 79.8936349))
# Path cached for SCSJ to SCRJ: [[6.90945, 79.894267], [6.909386, 79.894456], [6.909413, 79.894536], [6.909995, 79.894794], [6.910031, 79.894693]]... (total 7 points)
# Added path from SCSJ to SCRJ with 7 points
# Fetching path from SCRJ ((6.9103636, 79.8936349)) to SCNW ((6.9059941, 79.894945))
# Path cached for SCRJ to SCNW: [[6.910393, 79.893648], [6.910588, 79.893197], [6.910661, 79.893033], [6.910717, 79.893045], [6.910668, 79.893227]]... (total 28 points)
# Added path from SCRJ to SCNW with 28 points
# Fetching path from SCNW ((6.9059941, 79.894945)) to 14008 ((6.8964191, 79.8884819))
# Path cached for SCNW to 14008: [[6.905994, 79.894945], [6.905656, 79.89481], [6.90519, 79.894628], [6.905121, 79.894596], [6.904867, 79.894495]]... (total 67 points)
# Added path from SCNW to 14008 with 67 points
# Fetching path from 14008 ((6.8964191, 79.8884819)) to 1761 ((6.9038765, 79.8781829))
# Path cached for 14008 to 1761: [[6.896463, 79.888526], [6.896273, 79.888718], [6.895976, 79.888925], [6.895934, 79.889266], [6.895862, 79.889479]]... (total 62 points)
# Added path from 14008 to 1761 with 62 points
# Fetching path from 1761 ((6.9038765, 79.8781829)) to 1323 ((6.9038765, 79.8781829))
# Path cached for 1761 to 1323: [[6.903876, 79.878201], [6.903876, 79.878201]]... (total 2 points)
# Skipping path from 1761 to 1323 — insufficient points (2 points)
# Fetching path from 1323 ((6.9038765, 79.8781829)) to 1859 ((6.9110572, 79.8711168))
# Path cached for 1323 to 1859: [[6.903876, 79.878201], [6.903628, 79.878194], [6.903647, 79.877333], [6.903501, 79.877331], [6.903396, 79.877329]]... (total 52 points)
# Added path from 1323 to 1859 with 52 points
# Fetching path from 1859 ((6.9110572, 79.8711168)) to 1446 ((6.9160121, 79.8701693))
# Path cached for 1859 to 1446: [[6.911057, 79.871117], [6.911448, 79.870944], [6.912197, 79.87068], [6.912253, 79.870658], [6.912998, 79.870321]]... (total 20 points)
# Added path from 1859 to 1446 with 20 points
# Fetching path from 1446 ((6.9160121, 79.8701693)) to 1364 ((6.922196, 79.8645896))
# Path cached for 1446 to 1364: [[6.91619, 79.870207], [6.916222, 79.870056], [6.916232, 79.870012], [6.916286, 79.869754], [6.916347, 79.869466]]... (total 60 points)
# Added path from 1446 to 1364 with 60 points
# Fetching path from 1364 ((6.922196, 79.8645896)) to 0 ((7.0038321, 79.9394804))
# Path cached for 1364 to 0: [[6.922197, 79.864586], [6.922124, 79.864559], [6.921687, 79.864395], [6.921671, 79.864312], [6.922148, 79.864497]]... (total 574 points)
# Added path from 1364 to 0 with 574 points
# Plotted path for vehicle 2 with 1559 coordinates
# Processing route for vehicle 3: ['0', '14013', '171', '1137', 'SCMY', '1555', 'SCK7', '1108', 'SCKE', '1818', '1005', '1672', '1902', '1826', '1608', '1105', '0']
# Fetching path from 0 ((7.0038321, 79.9394804)) to 14013 ((7.0477897, 79.8970348))
# Path cached for 0 to 14013: [[7.003795, 79.939624], [7.003873, 79.939644], [7.003999, 79.939678], [7.004179, 79.93973], [7.004285, 79.939772]]... (total 351 points)
# Added path from 0 to 14013 with 351 points
# Fetching path from 14013 ((7.0477897, 79.8970348)) to 171 ((7.0477897, 79.8970348))
# Path cached for 14013 to 171: [[7.047801, 79.897033], [7.047801, 79.897033]]... (total 2 points)
# Skipping path from 14013 to 171 — insufficient points (2 points)
# Fetching path from 171 ((7.0477897, 79.8970348)) to 1137 ((6.9716722, 79.8786833))
# Path cached for 171 to 1137: [[7.047801, 79.897033], [7.047809, 79.897089], [7.047525, 79.897144], [7.047309, 79.897183], [7.047089, 79.897209]]... (total 300 points)
# Added path from 171 to 1137 with 300 points
# Fetching path from 1137 ((6.9716722, 79.8786833)) to SCMY ((6.9716722, 79.8786833))
# Path cached for 1137 to SCMY: [[6.971763, 79.878758], [6.971763, 79.878758]]... (total 2 points)
# Skipping path from 1137 to SCMY — insufficient points (2 points)
# Fetching path from SCMY ((6.9716722, 79.8786833)) to 1555 ((6.9529494, 79.8702837))
# Path cached for SCMY to 1555: [[6.971763, 79.878758], [6.971961, 79.878907], [6.972785, 79.878147], [6.972667, 79.878084], [6.972235, 79.877887]]... (total 90 points)
# Added path from SCMY to 1555 with 90 points
# Fetching path from 1555 ((6.9529494, 79.8702837)) to SCK7 ((6.9532197, 79.867138))
# Path cached for 1555 to SCK7: [[6.952701, 79.870633], [6.951748, 79.871056], [6.951296, 79.871248], [6.95103, 79.87137], [6.950855, 79.871454]]... (total 44 points)
# Added path from 1555 to SCK7 with 44 points
# Fetching path from SCK7 ((6.9532197, 79.867138)) to 1108 ((6.9486466, 79.859476))
# Path cached for SCK7 to 1108: [[6.953252, 79.867177], [6.953299, 79.867137], [6.953421, 79.866907], [6.953599, 79.866603], [6.953243, 79.866578]]... (total 51 points)
# Added path from SCK7 to 1108 with 51 points
# Fetching path from 1108 ((6.9486466, 79.859476)) to SCKE ((6.9481824, 79.8615896))
# Path cached for 1108 to SCKE: [[6.948757, 79.859538], [6.949213, 79.858719], [6.949273, 79.858611], [6.94935, 79.858645], [6.949289, 79.858761]]... (total 19 points)
# Added path from 1108 to SCKE with 19 points
# Fetching path from SCKE ((6.9481824, 79.8615896)) to 1818 ((6.9407856, 79.852666))
# Path cached for SCKE to 1818: [[6.948201, 79.861589], [6.948193, 79.86144], [6.948192, 79.861347], [6.948191, 79.861242], [6.948199, 79.861132]]... (total 78 points)
# Added path from SCKE to 1818 with 78 points
# Fetching path from 1818 ((6.9407856, 79.852666)) to 1005 ((6.9356673, 79.8447204))
# Path cached for 1818 to 1005: [[6.940982, 79.85245], [6.940721, 79.85221], [6.940576, 79.852062], [6.940448, 79.851927], [6.940305, 79.851746]]... (total 90 points)
# Added path from 1818 to 1005 with 90 points
# Fetching path from 1005 ((6.9356673, 79.8447204)) to 1672 ((6.9257119, 79.8503314))
# Path cached for 1005 to 1672: [[6.935622, 79.844975], [6.936009, 79.845045], [6.936075, 79.845054], [6.936117, 79.845092], [6.936178, 79.845184]]... (total 97 points)
# Added path from 1005 to 1672 with 97 points
# Fetching path from 1672 ((6.9257119, 79.8503314)) to 1902 ((6.9173305, 79.8554352))
# Path cached for 1672 to 1902: [[6.925718, 79.850373], [6.925925, 79.850341], [6.925731, 79.851027], [6.925418, 79.851137], [6.925525, 79.851684]]... (total 39 points)
# Added path from 1672 to 1902 with 39 points
# Fetching path from 1902 ((6.9173305, 79.8554352)) to 1826 ((6.9138726, 79.8525287))
# Path cached for 1902 to 1826: [[6.917206, 79.855504], [6.917109, 79.855327], [6.917021, 79.855099], [6.916808, 79.855277], [6.916633, 79.855424]]... (total 28 points)
# Added path from 1902 to 1826 with 28 points
# Fetching path from 1826 ((6.9138726, 79.8525287)) to 1608 ((6.9097726, 79.8501472))
# Path cached for 1826 to 1608: [[6.913771, 79.852559], [6.913553, 79.851805], [6.913375, 79.851373], [6.913347, 79.851333], [6.91331, 79.851303]]... (total 59 points)
# Added path from 1826 to 1608 with 59 points
# Fetching path from 1608 ((6.9097726, 79.8501472)) to 1105 ((6.9097726, 79.8501472))
# Path cached for 1608 to 1105: [[6.909782, 79.850144], [6.909782, 79.850144]]... (total 2 points)
# Skipping path from 1608 to 1105 — insufficient points (2 points)
# Fetching path from 1105 ((6.9097726, 79.8501472)) to 0 ((7.0038321, 79.9394804))
# Path cached for 1105 to 0: [[6.909782, 79.850144], [6.909789, 79.850167], [6.909885, 79.850139], [6.910117, 79.850069], [6.910152, 79.850059]]... (total 478 points)
# Added path from 1105 to 0 with 478 points
# Plotted path for vehicle 3 with 1724 coordinates
# Processing route for vehicle 4: ['0', 'SGSM', 'SCMU', '172', '1745', 'SCGT', 'SCWP', '1614', '1896', '1776', '1301', '1746', '1759', 'SCSL', '1545', 'SGKY', '0']
# Fetching path from 0 ((7.0038321, 79.9394804)) to SGSM ((6.9482114, 79.9386028))
# Path cached for 0 to SGSM: [[7.003795, 79.939624], [7.003747, 79.939611], [7.003646, 79.939576], [7.00356, 79.939533], [7.003509, 79.939495]]... (total 335 points)
# Added path from 0 to SGSM with 335 points
# Fetching path from SGSM ((6.9482114, 79.9386028)) to SCMU ((6.9289776, 79.9277399))
# Path cached for SGSM to SCMU: [[6.948236, 79.938583], [6.948257, 79.93861], [6.948624, 79.938351], [6.948638, 79.938341], [6.948913, 79.938147]]... (total 244 points)
# Added path from SGSM to SCMU with 244 points
# Fetching path from SCMU ((6.9289776, 79.9277399)) to 172 ((6.92695, 79.9307072))
# Path cached for SCMU to 172: [[6.928975, 79.927714], [6.928802, 79.927734], [6.928134, 79.927763], [6.928152, 79.928219], [6.928151, 79.928343]]... (total 15 points)
# Added path from SCMU to 172 with 15 points
# Fetching path from 172 ((6.92695, 79.9307072)) to 1745 ((6.9235507, 79.9136433))
# Path cached for 172 to 1745: [[6.92684, 79.930547], [6.926732, 79.930622], [6.926655, 79.930672], [6.926607, 79.930667], [6.926567, 79.930638]]... (total 97 points)
# Added path from 172 to 1745 with 97 points
# Fetching path from 1745 ((6.9235507, 79.9136433)) to SCGT ((6.9278516, 79.9106324))
# Path cached for 1745 to SCGT: [[6.923548, 79.913646], [6.923548, 79.913646], [6.923467, 79.913613], [6.92311, 79.913471], [6.923078, 79.913476]]... (total 43 points)
# Added path from 1745 to SCGT with 43 points
# Fetching path from SCGT ((6.9278516, 79.9106324)) to SCWP ((6.9319982, 79.907722))
# Path cached for SCGT to SCWP: [[6.927856, 79.910634], [6.928111, 79.90991], [6.928282, 79.909448], [6.928355, 79.909231], [6.928436, 79.909015]]... (total 46 points)
# Added path from SCGT to SCWP with 46 points
# Fetching path from SCWP ((6.9319982, 79.907722)) to 1614 ((6.9283596, 79.8949946))
# Path cached for SCWP to 1614: [[6.932247, 79.90813], [6.932554, 79.908106], [6.932673, 79.908042], [6.9329, 79.907927], [6.932925, 79.907812]]... (total 73 points)
# Added path from SCWP to 1614 with 73 points
# Fetching path from 1614 ((6.9283596, 79.8949946)) to 1896 ((6.9406131, 79.8789441))
# Path cached for 1614 to 1896: [[6.928478, 79.895172], [6.928478, 79.895172], [6.928554, 79.895129], [6.928694, 79.895074], [6.928844, 79.895033]]... (total 100 points)
# Added path from 1614 to 1896 with 100 points
# Fetching path from 1896 ((6.9406131, 79.8789441)) to 1776 ((6.9386902, 79.8747583))
# Path cached for 1896 to 1776: [[6.940814, 79.878926], [6.940768, 79.878405], [6.940763, 79.878352], [6.940294, 79.878341], [6.940167, 79.878338]]... (total 28 points)
# Added path from 1896 to 1776 with 28 points
# Fetching path from 1776 ((6.9386902, 79.8747583)) to 1301 ((6.9347204, 79.8685915))
# Path cached for 1776 to 1301: [[6.938624, 79.874857], [6.938964, 79.875089], [6.939118, 79.875224], [6.939188, 79.875281], [6.939112, 79.875404]]... (total 28 points)
# Added path from 1776 to 1301 with 28 points
# Fetching path from 1301 ((6.9347204, 79.8685915)) to 1746 ((6.9347092, 79.8674354))
# Path cached for 1301 to 1746: [[6.934695, 79.868595], [6.934689, 79.868547], [6.934779, 79.868519], [6.934904, 79.869558], [6.93541, 79.869424]]... (total 31 points)
# Added path from 1301 to 1746 with 31 points
# Fetching path from 1746 ((6.9347092, 79.8674354)) to 1759 ((6.930624, 79.8624312))
# Path cached for 1746 to 1759: [[6.934651, 79.867441], [6.934664, 79.867575], [6.934687, 79.867824], [6.934698, 79.867903], [6.934779, 79.868519]]... (total 42 points)
# Added path from 1746 to 1759 with 42 points
# Fetching path from 1759 ((6.930624, 79.8624312)) to SCSL ((6.9270786, 79.861243))
# Path cached for 1759 to SCSL: [[6.930535, 79.86234], [6.930708, 79.862168], [6.930901, 79.861967], [6.931084, 79.861782], [6.931594, 79.861262]]... (total 71 points)
# Added path from 1759 to SCSL with 71 points
# Fetching path from SCSL ((6.9270786, 79.861243)) to 1545 ((6.9381743, 79.8604831))
# Path cached for SCSL to 1545: [[6.927065, 79.86124], [6.927167, 79.860784], [6.927238, 79.860758], [6.927132, 79.861266], [6.927097, 79.8616]]... (total 88 points)
# Added path from SCSL to 1545 with 88 points
# Fetching path from 1545 ((6.9381743, 79.8604831)) to SGKY ((6.9512173, 79.9078132))
# Path cached for 1545 to SGKY: [[6.938192, 79.860714], [6.938249, 79.860709], [6.938293, 79.86072], [6.938431, 79.860798], [6.938504, 79.860897]]... (total 225 points)
# Added path from 1545 to SGKY with 225 points
# Fetching path from SGKY ((6.9512173, 79.9078132)) to 0 ((7.0038321, 79.9394804))
# Path cached for SGKY to 0: [[6.951262, 79.907811], [6.951263, 79.907849], [6.951261, 79.908507], [6.951291, 79.909026], [6.951307, 79.909482]]... (total 254 points)
# Added path from SGKY to 0 with 254 points
# Plotted path for vehicle 4 with 1720 coordinates
# Processing route for vehicle 5: ['0', 'SGJW', 'SGNO', 'SGJA', '1084', 'SGKC', 'SGSE', '128', 'SGNK', '26', 'SGND', '14007', 'SGN2', '123', 'SGMI', 'SGGE', '0']
# Fetching path from 0 ((7.0038321, 79.9394804)) to SGJW ((7.0673864, 79.8934866))
# Path cached for 0 to SGJW: [[7.003795, 79.939624], [7.003873, 79.939644], [7.003999, 79.939678], [7.004179, 79.93973], [7.004285, 79.939772]]... (total 457 points)
# Added path from 0 to SGJW with 457 points
# Fetching path from SGJW ((7.0673864, 79.8934866)) to SGNO ((7.0739735, 79.85717))
# Path cached for SGJW to SGNO: [[7.067387, 79.893485], [7.067693, 79.893719], [7.067857, 79.893815], [7.067951, 79.893858], [7.068076, 79.893903]]... (total 145 points)
# Added path from SGJW to SGNO with 145 points
# Fetching path from SGNO ((7.0739735, 79.85717)) to SGJA ((7.083344, 79.8926809))
# Path cached for SGNO to SGJA: [[7.073978, 79.857169], [7.07398, 79.857177], [7.07464, 79.857407], [7.075194, 79.857654], [7.075549, 79.85784]]... (total 132 points)
# Added path from SGNO to SGJA with 132 points
# Fetching path from SGJA ((7.083344, 79.8926809)) to 1084 ((7.091585, 79.8884605))
# Path cached for SGJA to 1084: [[7.083578, 79.892325], [7.083619, 79.892353], [7.084034, 79.892601], [7.084401, 79.892821], [7.084473, 79.892867]]... (total 63 points)
# Added path from SGJA to 1084 with 63 points
# Fetching path from 1084 ((7.091585, 79.8884605)) to SGKC ((7.091585, 79.8884605))
# Path cached for 1084 to SGKC: [[7.091587, 79.888477], [7.091587, 79.888477]]... (total 2 points)
# Skipping path from 1084 to SGKC — insufficient points (2 points)
# Fetching path from SGKC ((7.091585, 79.8884605)) to SGSE ((7.1231431, 79.8783888))
# Path cached for SGKC to SGSE: [[7.091587, 79.888477], [7.09186, 79.888433], [7.092288, 79.888378], [7.092365, 79.888363], [7.092454, 79.888336]]... (total 119 points)
# Added path from SGKC to SGSE with 119 points
# Fetching path from SGSE ((7.1231431, 79.8783888)) to 128 ((7.1247085, 79.8750028))
# Path cached for SGSE to 128: [[7.123153, 79.878411], [7.123484, 79.878261], [7.124138, 79.877986], [7.124745, 79.877762], [7.125279, 79.877622]]... (total 27 points)
# Added path from SGSE to 128 with 27 points
# Fetching path from 128 ((7.1247085, 79.8750028)) to SGNK ((7.1928611, 79.8604831))
# Path cached for 128 to SGNK: [[7.124831, 79.874984], [7.124874, 79.875261], [7.124889, 79.875455], [7.124918, 79.87566], [7.12771, 79.875469]]... (total 214 points)
# Added path from 128 to SGNK with 214 points
# Fetching path from SGNK ((7.1928611, 79.8604831)) to 26 ((7.2055208, 79.8512562))
# Path cached for SGNK to 26: [[7.193126, 79.861089], [7.193391, 79.860971], [7.195133, 79.860112], [7.195023, 79.859276], [7.194814, 79.856722]]... (total 41 points)
# Added path from SGNK to 26 with 41 points
# Fetching path from 26 ((7.2055208, 79.8512562)) to SGND ((7.2154132, 79.84165))
# Path cached for 26 to SGND: [[7.205523, 79.851261], [7.2055, 79.851271], [7.205506, 79.851177], [7.206275, 79.850834], [7.206814, 79.85059]]... (total 38 points)
# Added path from 26 to SGND with 38 points
# Fetching path from SGND ((7.2154132, 79.84165)) to 14007 ((7.2055208, 79.8512562))
# Path cached for SGND to 14007: [[7.215395, 79.84167], [7.215687, 79.841926], [7.216164, 79.84233], [7.216391, 79.842521], [7.217533, 79.843484]]... (total 46 points)
# Added path from SGND to 14007 with 46 points
# Fetching path from 14007 ((7.2055208, 79.8512562)) to SGN2 ((7.204378, 79.876023))
# Path cached for 14007 to SGN2: [[7.205523, 79.851261], [7.2055, 79.851271], [7.205405, 79.852063], [7.205268, 79.852786], [7.205214, 79.853101]]... (total 66 points)
# Added path from 14007 to SGN2 with 66 points
# Fetching path from SGN2 ((7.204378, 79.876023)) to 123 ((7.1842076, 79.9500477))
# Path cached for SGN2 to 123: [[7.204379, 79.876046], [7.204339, 79.876048], [7.204378, 79.876603], [7.204387, 79.876736], [7.204403, 79.877192]]... (total 188 points)
# Added path from SGN2 to 123 with 188 points
# Fetching path from 123 ((7.1842076, 79.9500477)) to SGMI ((7.1694282, 79.9520782))
# Path cached for 123 to SGMI: [[7.184602, 79.950551], [7.184547, 79.950595], [7.184223, 79.950949], [7.184157, 79.950998], [7.183753, 79.95118]]... (total 56 points)
# Added path from 123 to SGMI with 56 points
# Fetching path from SGMI ((7.1694282, 79.9520782)) to SGGE ((7.0603059, 79.9627325))
# Path cached for SGMI to SGGE: [[7.169404, 79.952082], [7.169306, 79.951425], [7.169241, 79.951076], [7.169106, 79.95065], [7.169037, 79.950297]]... (total 437 points)
# Added path from SGMI to SGGE with 437 points
# Fetching path from SGGE ((7.0603059, 79.9627325)) to 0 ((7.0038321, 79.9394804))
# Path cached for SGGE to 0: [[7.060336, 79.962736], [7.060336, 79.962736], [7.06035, 79.96268], [7.060314, 79.962677], [7.059359, 79.962581]]... (total 290 points)
# Added path from SGGE to 0 with 290 points
# Plotted path for vehicle 5 with 2319 coordinates
# Processing route for vehicle 6: ['0', 'SGMQ', '1355', '1548', '1549', 'SCAK', 'SCVJ', 'SCAR', 'SCPT', 'SCTH', 'SCBI', 'SLMN', '110', '14010', '1678', 'SCKX', '0']
# Fetching path from 0 ((7.0038321, 79.9394804)) to SGMQ ((6.9871489, 79.977399))
# Path cached for 0 to SGMQ: [[7.003795, 79.939624], [7.003873, 79.939644], [7.003999, 79.939678], [7.004179, 79.93973], [7.004285, 79.939772]]... (total 179 points)
# Added path from 0 to SGMQ with 179 points
# Fetching path from SGMQ ((6.9871489, 79.977399)) to 1355 ((6.9462153, 79.9892034))
# Path cached for SGMQ to 1355: [[6.987159, 79.9774], [6.987263, 79.976342], [6.987259, 79.975972], [6.987225, 79.975787], [6.987162, 79.975299]]... (total 196 points)
# Added path from SGMQ to 1355 with 196 points
# Fetching path from 1355 ((6.9462153, 79.9892034)) to 1548 ((6.9390215, 79.9871152))
# Path cached for 1355 to 1548: [[6.946179, 79.989205], [6.946183, 79.989293], [6.946279, 79.989406], [6.946263, 79.98989], [6.945869, 79.989822]]... (total 56 points)
# Added path from 1355 to 1548 with 56 points
# Fetching path from 1548 ((6.9390215, 79.9871152)) to 1549 ((6.9344434, 79.9961936))
# Path cached for 1548 to 1549: [[6.939022, 79.987113], [6.939096, 79.98712], [6.939424, 79.987132], [6.939768, 79.987144], [6.940038, 79.98715]]... (total 82 points)
# Added path from 1548 to 1549 with 82 points
# Fetching path from 1549 ((6.9344434, 79.9961936)) to SCAK ((6.8952571, 79.9505987))
# Path cached for 1549 to SCAK: [[6.934444, 79.996216], [6.934444, 79.996216], [6.934995, 79.996243], [6.935708, 79.996292], [6.935738, 79.995987]]... (total 319 points)
# Added path from 1549 to SCAK with 319 points
# Fetching path from SCAK ((6.8952571, 79.9505987)) to SCVJ ((6.8802431, 79.9475213))
# Path cached for SCAK to SCVJ: [[6.895286, 79.95061], [6.895235, 79.950746], [6.895182, 79.95088], [6.895104, 79.951144], [6.894993, 79.951563]]... (total 96 points)
# Added path from SCAK to SCVJ with 96 points
# Fetching path from SCVJ ((6.8802431, 79.9475213)) to SCAR ((6.8860799, 79.9626354))
# Path cached for SCVJ to SCAR: [[6.880268, 79.947524], [6.880279, 79.947423], [6.880296, 79.947667], [6.880286, 79.947839], [6.880302, 79.948224]]... (total 48 points)
# Added path from SCVJ to SCAR with 48 points
# Fetching path from SCAR ((6.8860799, 79.9626354)) to SCPT ((6.9087426, 79.9436659))
# Path cached for SCAR to SCPT: [[6.886122, 79.962672], [6.886722, 79.961979], [6.886929, 79.962188], [6.887096, 79.962351], [6.887641, 79.962858]]... (total 139 points)
# Added path from SCAR to SCPT with 139 points
# Fetching path from SCPT ((6.9087426, 79.9436659)) to SCTH ((6.9082532, 79.9447799))
# Path cached for SCPT to SCTH: [[6.908738, 79.943665], [6.908715, 79.943752], [6.908686, 79.943845], [6.908636, 79.943997], [6.908567, 79.944202]]... (total 13 points)
# Added path from SCPT to SCTH with 13 points
# Fetching path from SCTH ((6.9082532, 79.9447799)) to SCBI ((6.9084066, 79.9446174))
# Path cached for SCTH to SCBI: [[6.908248, 79.944775], [6.908296, 79.944725], [6.908363, 79.944642], [6.908424, 79.944546], [6.908409, 79.944617]]... (total 5 points)
# Added path from SCTH to SCBI with 5 points
# Fetching path from SCBI ((6.9084066, 79.9446174)) to SLMN ((6.9084066, 79.9446174))
# Path cached for SCBI to SLMN: [[6.908409, 79.944617], [6.908409, 79.944617]]... (total 2 points)
# Skipping path from SCBI to SLMN — insufficient points (2 points)
# Fetching path from SLMN ((6.9084066, 79.9446174)) to 110 ((6.9060787, 79.9696277))
# Path cached for SLMN to 110: [[6.908409, 79.944617], [6.908373, 79.944793], [6.908356, 79.944839], [6.908305, 79.944998], [6.908292, 79.945113]]... (total 149 points)
# Added path from SLMN to 110 with 149 points
# Fetching path from 110 ((6.9060787, 79.9696277)) to 14010 ((6.9060787, 79.9696277))
# Path cached for 110 to 14010: [[6.906259, 79.96967], [6.906259, 79.96967]]... (total 2 points)
# Skipping path from 110 to 14010 — insufficient points (2 points)
# Fetching path from 14010 ((6.9060787, 79.9696277)) to 1678 ((6.9194938, 79.9780178))
# Path cached for 14010 to 1678: [[6.906259, 79.96967], [6.906256, 79.969685], [6.906269, 79.96971], [6.906334, 79.969726], [6.906754, 79.969757]]... (total 78 points)
# Added path from 14010 to 1678 with 78 points
# Fetching path from 1678 ((6.9194938, 79.9780178)) to SCKX ((6.9313808, 79.9766195))
# Path cached for 1678 to SCKX: [[6.919471, 79.978272], [6.919827, 79.978305], [6.919831, 79.978439], [6.919806, 79.978494], [6.919832, 79.978647]]... (total 103 points)
# Added path from 1678 to SCKX with 103 points
# Fetching path from SCKX ((6.9313808, 79.9766195)) to 0 ((7.0038321, 79.9394804))
# Path cached for SCKX to 0: [[6.931009, 79.976897], [6.931063, 79.977046], [6.931115, 79.977182], [6.93115, 79.977292], [6.931175, 79.97741]]... (total 208 points)
# Added path from SCKX to 0 with 208 points
# Plotted path for vehicle 6 with 1671 coordinates
# Processing route for vehicle 7: ['0', 'SGEM', 'SGKG', 'SGKB', '14', 'SGTY', 'SGKR', 'SGWA', '14015', '117', '3', 'SGMH', 'SGRA', '150', 'SGEL', 'SGK5', '0']
# Fetching path from 0 ((7.0038321, 79.9394804)) to SGEM ((6.9977837, 79.9189814))
# Path cached for 0 to SGEM: [[7.003795, 79.939624], [7.003747, 79.939611], [7.003646, 79.939576], [7.00356, 79.939533], [7.003509, 79.939495]]... (total 147 points)
# Added path from 0 to SGEM with 147 points
# Fetching path from SGEM ((6.9977837, 79.9189814)) to SGKG ((6.9786855, 79.9277))
# Path cached for SGEM to SGKG: [[6.997787, 79.918937], [6.997242, 79.918901], [6.996976, 79.918794], [6.996767, 79.918737], [6.996394, 79.918704]]... (total 144 points)
# Added path from SGEM to SGKG with 144 points
# Fetching path from SGKG ((6.9786855, 79.9277)) to SGKB ((6.9773951, 79.9296825))
# Path cached for SGKG to SGKB: [[6.978703, 79.927682], [6.978716, 79.927695], [6.980099, 79.928999], [6.980054, 79.929047], [6.978721, 79.927819]]... (total 17 points)
# Added path from SGKG to SGKB with 17 points
# Fetching path from SGKB ((6.9773951, 79.9296825)) to 14 ((6.9778284, 79.9271523))
# Path cached for SGKB to 14: [[6.977389, 79.929681], [6.977425, 79.92955], [6.977526, 79.929194], [6.977681, 79.928467], [6.977784, 79.928005]]... (total 12 points)
# Added path from SGKB to 14 with 12 points
# Fetching path from 14 ((6.9778284, 79.9271523)) to SGTY ((6.9736276, 79.9208395))
# Path cached for 14 to SGTY: [[6.977938, 79.927045], [6.977209, 79.926287], [6.976737, 79.925786], [6.976625, 79.925678], [6.976593, 79.925648]]... (total 21 points)
# Added path from 14 to SGTY with 21 points
# Fetching path from SGTY ((6.9736276, 79.9208395)) to SGKR ((6.9906677, 79.8931709))
# Path cached for SGTY to SGKR: [[6.9736, 79.920847], [6.973586, 79.920792], [6.973507, 79.920399], [6.973476, 79.920247], [6.973444, 79.920091]]... (total 131 points)
# Added path from SGTY to SGKR with 131 points
# Fetching path from SGKR ((6.9906677, 79.8931709)) to SGWA ((6.9887181, 79.8913253))
# Path cached for SGKR to SGWA: [[6.99068, 79.893155], [6.990696, 79.893167], [6.990648, 79.893259], [6.990088, 79.892827], [6.989947, 79.892717]]... (total 15 points)
# Added path from SGKR to SGWA with 15 points
# Fetching path from SGWA ((6.9887181, 79.8913253)) to 14015 ((6.9906677, 79.8931709))
# Path cached for SGWA to 14015: [[6.988635, 79.891418], [6.98889, 79.891651], [6.989333, 79.892056], [6.989438, 79.892152], [6.989707, 79.892392]]... (total 8 points)
# Added path from SGWA to 14015 with 8 points
# Fetching path from 14015 ((6.9906677, 79.8931709)) to 117 ((6.9906677, 79.8931709))
# Path cached for 14015 to 117: [[6.99068, 79.893155], [6.99068, 79.893155]]... (total 2 points)
# Skipping path from 14015 to 117 — insufficient points (2 points)
# Fetching path from 117 ((6.9906677, 79.8931709)) to 3 ((6.9906677, 79.8931709))
# Path cached for 117 to 3: [[6.99068, 79.893155], [6.99068, 79.893155]]... (total 2 points)
# Skipping path from 117 to 3 — insufficient points (2 points)
# Fetching path from 3 ((6.9906677, 79.8931709)) to SGMH ((7.0243153, 79.899739))
# Path cached for 3 to SGMH: [[6.99068, 79.893155], [6.990696, 79.893167], [6.990985, 79.89339], [6.991576, 79.893823], [6.991792, 79.893972]]... (total 116 points)
# Added path from 3 to SGMH with 116 points
# Fetching path from SGMH ((7.0243153, 79.899739)) to SGRA ((7.0270252, 79.9150162))
# Path cached for SGMH to SGRA: [[7.024315, 79.899748], [7.024398, 79.89975], [7.024508, 79.899747], [7.02451, 79.899827], [7.024398, 79.89983]]... (total 75 points)
# Added path from SGMH to SGRA with 75 points
# Fetching path from SGRA ((7.0270252, 79.9150162)) to 150 ((7.0280037, 79.923))
# Path cached for SGRA to 150: [[7.026996, 79.915248], [7.027151, 79.915268], [7.027358, 79.915283], [7.027927, 79.915311], [7.027926, 79.915429]]... (total 39 points)
# Added path from SGRA to 150 with 39 points
# Fetching path from 150 ((7.0280037, 79.923)) to SGEL ((7.0147657, 79.9690126))
# Path cached for 150 to SGEL: [[7.028008, 79.923069], [7.028146, 79.92306], [7.028219, 79.922752], [7.028246, 79.922501], [7.028234, 79.922152]]... (total 282 points)
# Added path from 150 to SGEL with 282 points
# Fetching path from SGEL ((7.0147657, 79.9690126)) to SGK5 ((7.0371109, 79.9917576))
# Path cached for SGEL to SGK5: [[7.014732, 79.969051], [7.014784, 79.969098], [7.014846, 79.969146], [7.014894, 79.969176], [7.014912, 79.969188]]... (total 178 points)
# Added path from SGEL to SGK5 with 178 points
# Fetching path from SGK5 ((7.0371109, 79.9917576)) to 0 ((7.0038321, 79.9394804))
# Path cached for SGK5 to 0: [[7.037112, 79.991753], [7.037212, 79.991785], [7.037504, 79.991879], [7.03765, 79.991936], [7.037798, 79.991999]]... (total 432 points)
# Added path from SGK5 to 0 with 432 points
# Plotted path for vehicle 7 with 1617 coordinates
# Saved 128 cached routes to ../data/csv/route_cache.csv
# Saved 334 unvisited nodes to output/csv/next_day_demand.csv for next-day processing.
