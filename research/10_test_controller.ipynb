# %%
# from vehi_rout.controller import VRPController

# %%
import pandas as pd
from datetime import datetime
import os

from vehi_rout.config import (
    TOTAL_DAYS,
    DISTANCE_BASE_PENALTY,
    TIME_BASE_PENALTY
)
from vehi_rout.utils.data_utils import (
    load_matrix_df,
    load_df,
    get_demand_df,
    update_demand_dic
)
from vehi_rout.utils.helper_utils import (
    get_penalty_list,
    get_values_not_in_second_list
)
from vehi_rout.utils.route_utils import sort_nodes_by_distance
from vehi_rout.utils.visualization import (
    visualize_routes_per_vehicle,
    print_route_summary,
    save_route_details_to_csv
)
from vehi_rout.solver.vrp_solver import (
    solve_vrp_for_day,
    solve_multi_day_vrp
)

class VRPController:
    """Controller class for the Vehicle Routing Problem."""

    def __init__(self, use_distance=True):
        """
        Initialize the VRP controller.

        Args:
            use_distance: Boolean indicating whether to use distance or time
        """
        self.use_distance = use_distance
        self.base_penalty = DISTANCE_BASE_PENALTY if use_distance else TIME_BASE_PENALTY
        self.demand_df = None
        self.master_mat_df = None
        self.master_gps_df = None
        self.demand_dict = None
        self.penalty_list = None

    def load_data(self, demand_path, matrix_path, gps_path):
        """
        Load data from files.

        Args:
            demand_path: Path to the demand file
            matrix_path: Path to the distance/time matrix file
            gps_path: Path to the GPS coordinates file
        """
        self.demand_df = get_demand_df(today_path=demand_path)
        if self.demand_df['CODE'].dtype in ['float', 'int', 'int64']:
            self.demand_df['CODE'] = self.demand_df['CODE'].astype(int)
            self.demand_df['CODE'] = self.demand_df['CODE'].astype(str)
            print('Converting CODE to string')

        self.master_mat_df = load_matrix_df(path=matrix_path)
        self.master_gps_df = load_df(path=gps_path)

        SMAK_KADAWATHA = (7.0038321, 79.9394804)
        smak_data = {
            "CODE": '0',
            "LOCATION": "SMAK",
            "ADDRESS": "Smak, Kadawatha, Western Province, Sri Lanka",
            "LATITUDE": SMAK_KADAWATHA[0],
            "LONGITUDE": SMAK_KADAWATHA[1]
        }

        if '0' in self.master_gps_df['CODE'].values:
            self.master_gps_df = self.master_gps_df[self.master_gps_df['CODE'] != '0']

        self.master_gps_df = pd.concat(
            [pd.DataFrame([smak_data]), self.master_gps_df],
            ignore_index=True
        )
        print("Added depot (SMAK_KADAWATHA) to GPS data")

        self.demand_dict = update_demand_dic(self.demand_df)
        today = datetime.now().strftime('%Y-%m-%d')
        self.penalty_list = get_penalty_list(self.demand_dict, self.base_penalty, TOTAL_DAYS, today)

        print(f"Loaded {len(self.demand_df)} demand records")
        print(f"Loaded {len(self.master_mat_df)} locations in distance/time matrix")
        print(f"Loaded {len(self.master_gps_df)} locations with GPS coordinates")

    def solve_single_day(self, day=0, max_nodes=None, save_visualization=False):
        """
        Solve the VRP for a single day.

        Args:
            day: Day index (0-based)
            max_nodes: Maximum number of nodes to visit
            save_visualization: Boolean indicating whether to save visualization

        Returns:
            visited_nodes: Set of visited node indices
            route_dict: Dictionary containing route information for each vehicle
        """
        if self.demand_df is None or self.master_mat_df is None or self.master_gps_df is None:
            raise ValueError("Data not loaded. Call load_data() first.")

        all_nodes = list(range(1, len(self.master_mat_df)))
        sorted_nodes = sort_nodes_by_distance(self.master_mat_df.values)

        if max_nodes is not None and max_nodes < len(sorted_nodes):
            nodes_to_visit = sorted(sorted_nodes[:max_nodes])
        else:
            nodes_to_visit = all_nodes

        visited_nodes, route_dict = solve_vrp_for_day(
            self.master_mat_df,
            nodes_to_visit,
            day,
            self.demand_dict,
            self.penalty_list,
            self.use_distance
        )

        self._create_output_directories()
        summary_file = f"output/summaries/day_{day + 1}_summary.txt"
        print_route_summary(route_dict, self.use_distance, file_path=summary_file)

        csv_file = f"output/csv/day_{day + 1}_routes.csv"
        save_route_details_to_csv(self.demand_df, route_dict, day, self.use_distance, file_path=csv_file)

        if save_visualization:
            maps_dict = visualize_routes_per_vehicle(
                self.master_gps_df,
                route_dict,
                day,
                use_distance=self.use_distance
            )
            os.makedirs("output/maps", exist_ok=True)
            for vehicle_id, m in maps_dict.items():
                m.save(f"output/maps/day_{day + 1}_vehicle_{vehicle_id}_route.html")

        all_po_nodes = self.get_po_node_indices()
        unvisited = all_po_nodes - visited_nodes
        self._save_unvisited_nodes_to_csv(unvisited)

        return visited_nodes, route_dict

    def solve_multi_day(self, total_days=None, max_nodes=None, save_visualization=False):
        """
        Solve the VRP for multiple days.

        Args:
            total_days: Number of days to plan
            max_nodes: Maximum number of nodes to visit per day
            save_visualization: Boolean indicating whether to save visualization

        Returns:
            all_visited_nodes: List of sets of visited node indices for each day
            all_route_dicts: List of dictionaries containing route information for each day
        """
        if self.demand_df is None or self.master_mat_df is None or self.master_gps_df is None:
            raise ValueError("Data not loaded. Call load_data() first.")

        if total_days is None:
            total_days = TOTAL_DAYS

        all_visited_nodes, all_route_dicts = solve_multi_day_vrp(
            self.master_mat_df,
            self.demand_dict,
            total_days,
            self.base_penalty,
            self.use_distance,
            current_date=None,
            max_nodes_per_day=max_nodes
        )

        self._create_output_directories()
        combined_csv_path = f"output/csv/all_days_routes.csv"
        import csv
        with open(combined_csv_path, 'w', newline='') as csvfile:
            metric_name = "distance" if self.use_distance else "time"
            unit = "km" if self.use_distance else "mins"
            fieldnames = ['Day', 'Vehicle', 'Stops', f'{metric_name.capitalize()} ({unit})',
                         f'Max {metric_name.capitalize()} ({unit})', 'Within Limit', 'Route']
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()

        for day, route_dict in enumerate(all_route_dicts):
            print(f"\n=== Day {day + 1} ===")
            if not isinstance(route_dict, dict):
                print(f"Warning: Invalid route_dict for day {day + 1} (got {type(route_dict)}), skipping.")
                continue

            summary_file = f"output/summaries/day_{day + 1}_summary.txt"
            print_route_summary(route_dict, self.use_distance, file_path=summary_file)

            csv_file = f"output/csv/day_{day + 1}_routes.csv"
            save_route_details_to_csv(self.demand_df, route_dict, day, self.use_distance, file_path=csv_file)

            self._append_to_combined_csv(route_dict, day, combined_csv_path)

            if save_visualization:
                maps_dict = visualize_routes_per_vehicle(
                    self.master_gps_df,
                    route_dict,
                    day,
                    use_distance=self.use_distance
                )
                for vehicle_id, m in maps_dict.items():
                    m.save(f"output/maps/day_{day + 1}_vehicle_{vehicle_id}_route.html")

        self._save_multi_day_summary(all_route_dicts, all_visited_nodes)

        return all_visited_nodes, all_route_dicts

    def _append_to_combined_csv(self, route_dict, day, file_path):
        """
        Append route information to a combined CSV file.

        Args:
            route_dict: Dictionary containing route information for each vehicle
            day: Day index (0-based)
            file_path: Path to the CSV file
        """
        if not isinstance(route_dict, dict):
            print(f"Warning: Cannot append to combined CSV for day {day + 1}, route_dict is not a dictionary.")
            return

        import csv
        metric_name = "distance" if self.use_distance else "time"
        unit = "km" if self.use_distance else "mins"

        with open(file_path, 'a', newline='') as csvfile:
            fieldnames = ['Day', 'Vehicle', 'Stops', f'{metric_name.capitalize()} ({unit})',
                         f'Max {metric_name.capitalize()} ({unit})', 'Within Limit', 'Route']
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

            for vehicle_id, route_info in route_dict.items():
                route_metric = route_info.get(f"route_{metric_name}", 0)
                num_visits = route_info.get("num_visits", 0)
                max_metric = route_info.get(f"max_{metric_name}_limit", 0)
                within_limit = route_info.get("within_limit", False)
                route_nodes = ' -> '.join(map(str, route_info.get("route_nodes", [])))

                writer.writerow({
                    'Day': day + 1,
                    'Vehicle': vehicle_id,
                    'Stops': num_visits,
                    f'{metric_name.capitalize()} ({unit})': route_metric,
                    f'Max {metric_name.capitalize()} ({unit})': max_metric,
                    'Within Limit': 'Yes' if within_limit else 'No',
                    'Route': route_nodes
                })

    def _save_multi_day_summary(self, all_route_dicts, all_visited_nodes):
        """
        Save a summary of the multi-day routing and create a next-day demand file.

        Args:
            all_route_dicts: List of dictionaries containing route information for each day
            all_visited_nodes: List of sets of visited node indices for each day
        """
        metric_name = "distance" if self.use_distance else "time"
        unit = "km" if self.use_distance else "mins"

        total_metric = 0
        total_visits = 0
        valid_days = 0

        for route_dict in all_route_dicts:
            if not isinstance(route_dict, dict):
                print(f"Warning: Skipping invalid route_dict in multi-day summary (got {type(route_dict)}).")
                continue
            valid_days += 1
            for vehicle_id, route_info in route_dict.items():
                total_metric += route_info.get(f"route_{metric_name}", 0)
                total_visits += route_info.get("num_visits", 0)

        all_visited = set()
        for visited in all_visited_nodes:
            all_visited.update(visited)

        all_po_nodes = self.get_po_node_indices()
        unvisited = all_po_nodes - all_visited

        summary_lines = []
        summary_lines.append(f"Multi-Day Routing Summary")
        summary_lines.append(f"-" * 50)
        summary_lines.append(f"Total days processed: {valid_days}")
        summary_lines.append(f"Total vehicles: {len(all_route_dicts[0]) if all_route_dicts and isinstance(all_route_dicts[0], dict) else 0}")
        summary_lines.append(f"Total stops: {total_visits}")
        summary_lines.append(f"Total {metric_name}: {total_metric} {unit}")
        summary_lines.append(f"Total nodes visited: {len(all_visited)}")
        summary_lines.append(f"Total nodes unvisited: {len(unvisited)}")
        summary_lines.append(f"-" * 50)

        summary_file = "output/summaries/multi_day_summary.txt"
        with open(summary_file, 'w') as f:
            for line in summary_lines:
                f.write(line + '\n')

            if unvisited:
                f.write(f"\nUnvisited nodes:\n")
                unvisited_codes = [code for code in unvisited if code in self.master_mat_df.index]
                for i, code in enumerate(unvisited_codes):
                    f.write(f"{code}")
                    if (i + 1) % 10 == 0:
                        f.write("\n")
                    else:
                        f.write(", ")

        print(f"Multi-day summary saved to {summary_file}")
        self._save_unvisited_nodes_to_csv(unvisited)

    def _create_output_directories(self):
        """
        Create output directories for saving results.
        """
        os.makedirs("output", exist_ok=True)
        os.makedirs("output/summaries", exist_ok=True)
        os.makedirs("output/csv", exist_ok=True)
        os.makedirs("output/maps", exist_ok=True)

    def get_po_node_indices(self):
        """
        Get the indices of nodes in the purchase order (PO) file.

        Returns:
            set: Set of node indices from the PO file
        """
        po_node_indices = set(str(code) for code in self.demand_dict['key'] if str(code) in self.master_mat_df.index)
        return po_node_indices

    def _save_unvisited_nodes_to_csv(self, unvisited):
        """
        Save unvisited nodes to a CSV file for next-day processing.

        Args:
            unvisited: Set of unvisited node indices
        """
        import pandas as pd

        unvisited_codes = list(unvisited)
        if not unvisited_codes:
            print("No unvisited nodes to save for next day.")
            return

        next_day_df = pd.DataFrame()
        if self.demand_df is not None:
            unvisited_codes_set = set(str(code) for code in unvisited_codes)
            next_day_df = self.demand_df[self.demand_df['CODE'].astype(str).isin(unvisited_codes_set)].copy()

        if next_day_df.empty:
            print("Warning: Could not find demand data for unvisited nodes.")
            next_day_df = pd.DataFrame({'CODE': unvisited_codes})

        if 'DEMAND' in next_day_df.columns:
            next_day_df.drop(columns=['DEMAND'], inplace=True)

        next_day_file = "output/csv/next_day_demand.csv"
        next_day_df.to_csv(next_day_file, index=False)
        print(f"Saved {len(next_day_df)} unvisited nodes to {next_day_file} for next-day processing.")

    def update_vehicle_config(self, num_vehicles, max_visits, max_distance):
        """
        Update the vehicle configuration parameters.

        Args:
            num_vehicles: Number of vehicles
            max_visits: List of maximum visits per vehicle
            max_distance: List of maximum distance per vehicle
        """
        if len(max_visits) != num_vehicles or len(max_distance) != num_vehicles:
            raise ValueError("Length of max_visits and max_distance must match num_vehicles")

        new_max_visits = max_visits.copy()
        new_max_distance = max_distance.copy()

        self.max_distance = new_max_distance
        self.max_visits = new_max_visits

        import vehi_rout.config as config
        config.MAX_VISITS_PER_VEHICLE = new_max_visits
        config.MAX_DISTANCE_PER_VEHICLE = new_max_distance

        print(f"Updated vehicle configuration:")
        print(f"Number of vehicles: {num_vehicles}")
        print(f"Max visits per vehicle: {new_max_visits}")
        print(f"Max distance per vehicle: {new_max_distance}")

# %%
controller = VRPController()

# %%
matrix_path = '../data/master/osrm_distance_matrix.csv'
gps_path = '../data/master/master_gps.csv'
demand_path = '../data/test/orders/03-03-2025-PO.csv'  #'output/csv/next_day_demand.csv'

controller.load_data(
    demand_path=demand_path,
    matrix_path=matrix_path,
    gps_path=gps_path
)

num_vehicles=8
max_visits = [15, 15, 15, 15, 15, 15, 15, 15]
max_distance =[300, 300, 300, 300, 300, 300, 300, 300]


controller.update_vehicle_config(num_vehicles, max_visits, max_distance)

visited_nodes, route_dict =controller.solve_single_day(save_visualization=True)
# Out:
# Added depot (SMAK_KADAWATHA) to GPS data
# Loaded 457 demand records
# Loaded 651 locations in distance/time matrix
# Loaded 651 locations with GPS coordinates
# Updated vehicle configuration:
# Number of vehicles: 8
# Max visits per vehicle: [15, 15, 15, 15, 15, 15, 15, 15]
# Max distance per vehicle: [300, 300, 300, 300, 300, 300, 300, 300]
# Max Distance: [300, 300, 300, 300, 300, 300, 300, 300]
#
# Day 1 Routes (Penalty per unvisited demand unit: 100000 km):
# Route for vehicle 0:
#  0 -> 1109 -> SCHR -> 1305 -> 1650 -> 25 -> 1594 -> 1291 -> 1308 -> 1130 -> 1033 -> SCMD -> SCDP -> 1411 -> 1661 -> SCSL -> 0
# Distance of the route: 42 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 1:
#  0 -> SGEM -> 14011 -> 1676 -> 1419 -> SCTU -> 1017 -> 5 -> 1902 -> SCUP -> 1303 -> 14003 -> 1433 -> 1145 -> 1364 -> 1292 -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 2:
#  0 -> 1728 -> 1497 -> 1872 -> 1471 -> 1320 -> SCCR -> SCSJ -> SCRJ -> SCNW -> 14008 -> SCTB -> 1888 -> 1107 -> 1323 -> 1761 -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 3:
#  0 -> 1137 -> SCMY -> 1555 -> SCK7 -> 1108 -> SCKE -> 1818 -> 1005 -> 1672 -> SCCC -> 1826 -> 1608 -> 1105 -> 1446 -> 1859 -> 0
# Distance of the route: 39 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 4:
#  0 -> SGMP -> 24 -> SGGP -> SGMI -> 123 -> SGN2 -> SGNK -> 128 -> SGSE -> SGKC -> 1084 -> SGJA -> SGNO -> SGJW -> 171 -> 0
# Distance of the route: 76 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 5:
#  0 -> SGSM -> SCMU -> 172 -> 1745 -> SCGT -> SCWP -> 1614 -> 1896 -> 1776 -> 1301 -> 1746 -> 1759 -> SCDR -> 1545 -> SGKY -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 6:
#  0 -> SGMQ -> 1355 -> 1548 -> 1549 -> SCAK -> SCVJ -> SCAR -> SCPT -> SCTH -> SCBI -> SLMN -> 110 -> 14010 -> 1678 -> SCKX -> 0
# Distance of the route: 50 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 7:
#  0 -> SGKB -> SGKG -> 14 -> SGTY -> 14015 -> SGKR -> SGWA -> 3 -> 14013 -> SGMH -> SGRA -> 150 -> SGGE -> SGK5 -> SGEL -> 0
# Distance of the route: 37 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Maximum route distance for Day 1: 76 km
# Route Summary:
#     Vehicle    Stops      Distance        Within Limit
# -------------------------------------------------------
#     0          15         42         km   Yes
#     1          15         36         km   Yes
#     2          15         36         km   Yes
#     3          15         39         km   Yes
#     4          15         76         km   Yes
#     5          15         36         km   Yes
#     6          15         50         km   Yes
#     7          15         37         km   Yes
# -------------------------------------------------------
#     Total      120        352        km
# Summary saved to output/summaries/day_1_summary.txt
# Route details saved to output/csv/day_1_routes.csv
# Processing route for vehicle 0: ['0', '1109', 'SCHR', '1305', '1650', '25', '1594', '1291', '1308', '1130', '1033', 'SCMD', 'SCDP', '1411', '1661', 'SCSL', '0']
# Using cached path for 0 to 1109
# Added path from 0 to 1109 with 549 points
# Using cached path for 1109 to SCHR
# Added path from 1109 to SCHR with 76 points
# Using cached path for SCHR to 1305
# Added path from SCHR to 1305 with 44 points
# Using cached path for 1305 to 1650
# Added path from 1305 to 1650 with 59 points
# Using cached path for 1650 to 25
# Added path from 1650 to 25 with 27 points
# Using cached path for 25 to 1594
# Added path from 25 to 1594 with 59 points
# Using cached path for 1594 to 1291
# Added path from 1594 to 1291 with 16 points
# Using cached path for 1291 to 1308
# Added path from 1291 to 1308 with 47 points
# Using cached path for 1308 to 1130
# Skipping path from 1308 to 1130 — insufficient points (2 points)
# Using cached path for 1130 to 1033
# Added path from 1130 to 1033 with 27 points
# Using cached path for 1033 to SCMD
# Added path from 1033 to SCMD with 31 points
# Using cached path for SCMD to SCDP
# Added path from SCMD to SCDP with 34 points
# Using cached path for SCDP to 1411
# Added path from SCDP to 1411 with 61 points
# Using cached path for 1411 to 1661
# Added path from 1411 to 1661 with 121 points
# Using cached path for 1661 to SCSL
# Added path from 1661 to SCSL with 77 points
# Using cached path for SCSL to 0
# Added path from SCSL to 0 with 552 points
# Plotted path for vehicle 0 with 1780 coordinates
# Processing route for vehicle 1: ['0', 'SGEM', '14011', '1676', '1419', 'SCTU', '1017', '5', '1902', 'SCUP', '1303', '14003', '1433', '1145', '1364', '1292', '0']
# Using cached path for 0 to SGEM
# Added path from 0 to SGEM with 147 points
# Using cached path for SGEM to 14011
# Added path from SGEM to 14011 with 391 points
# Using cached path for 14011 to 1676
# Added path from 14011 to 1676 with 8 points
# Using cached path for 1676 to 1419
# Added path from 1676 to 1419 with 28 points
# Using cached path for 1419 to SCTU
# Added path from 1419 to SCTU with 57 points
# Using cached path for SCTU to 1017
# Added path from SCTU to 1017 with 86 points
# Using cached path for 1017 to 5
# Added path from 1017 to 5 with 36 points
# Using cached path for 5 to 1902
# Added path from 5 to 1902 with 28 points
# Using cached path for 1902 to SCUP
# Added path from 1902 to SCUP with 27 points
# Using cached path for SCUP to 1303
# Added path from SCUP to 1303 with 51 points
# Using cached path for 1303 to 14003
# Added path from 1303 to 14003 with 24 points
# Using cached path for 14003 to 1433
# Added path from 14003 to 1433 with 10 points
# Using cached path for 1433 to 1145
# Added path from 1433 to 1145 with 20 points
# Using cached path for 1145 to 1364
# Added path from 1145 to 1364 with 27 points
# Using cached path for 1364 to 1292
# Added path from 1364 to 1292 with 125 points
# Using cached path for 1292 to 0
# Added path from 1292 to 0 with 416 points
# Plotted path for vehicle 1 with 1481 coordinates
# Processing route for vehicle 2: ['0', '1728', '1497', '1872', '1471', '1320', 'SCCR', 'SCSJ', 'SCRJ', 'SCNW', '14008', 'SCTB', '1888', '1107', '1323', '1761', '0']
# Using cached path for 0 to 1728
# Added path from 0 to 1728 with 423 points
# Using cached path for 1728 to 1497
# Added path from 1728 to 1497 with 28 points
# Using cached path for 1497 to 1872
# Added path from 1497 to 1872 with 103 points
# Using cached path for 1872 to 1471
# Added path from 1872 to 1471 with 37 points
# Using cached path for 1471 to 1320
# Added path from 1471 to 1320 with 23 points
# Using cached path for 1320 to SCCR
# Added path from 1320 to SCCR with 44 points
# Using cached path for SCCR to SCSJ
# Added path from SCCR to SCSJ with 31 points
# Using cached path for SCSJ to SCRJ
# Added path from SCSJ to SCRJ with 7 points
# Using cached path for SCRJ to SCNW
# Added path from SCRJ to SCNW with 28 points
# Using cached path for SCNW to 14008
# Added path from SCNW to 14008 with 67 points
# Using cached path for 14008 to SCTB
# Added path from 14008 to SCTB with 84 points
# Using cached path for SCTB to 1888
# Added path from SCTB to 1888 with 27 points
# Using cached path for 1888 to 1107
# Added path from 1888 to 1107 with 27 points
# Using cached path for 1107 to 1323
# Added path from 1107 to 1323 with 53 points
# Using cached path for 1323 to 1761
# Skipping path from 1323 to 1761 — insufficient points (2 points)
# Using cached path for 1761 to 0
# Added path from 1761 to 0 with 408 points
# Plotted path for vehicle 2 with 1390 coordinates
# Processing route for vehicle 3: ['0', '1137', 'SCMY', '1555', 'SCK7', '1108', 'SCKE', '1818', '1005', '1672', 'SCCC', '1826', '1608', '1105', '1446', '1859', '0']
# Using cached path for 0 to 1137
# Added path from 0 to 1137 with 421 points
# Using cached path for 1137 to SCMY
# Skipping path from 1137 to SCMY — insufficient points (2 points)
# Using cached path for SCMY to 1555
# Added path from SCMY to 1555 with 90 points
# Using cached path for 1555 to SCK7
# Added path from 1555 to SCK7 with 44 points
# Using cached path for SCK7 to 1108
# Added path from SCK7 to 1108 with 51 points
# Using cached path for 1108 to SCKE
# Added path from 1108 to SCKE with 19 points
# Using cached path for SCKE to 1818
# Added path from SCKE to 1818 with 78 points
# Using cached path for 1818 to 1005
# Added path from 1818 to 1005 with 90 points
# Using cached path for 1005 to 1672
# Added path from 1005 to 1672 with 97 points
# Using cached path for 1672 to SCCC
# Added path from 1672 to SCCC with 65 points
# Using cached path for SCCC to 1826
# Added path from SCCC to 1826 with 43 points
# Using cached path for 1826 to 1608
# Added path from 1826 to 1608 with 59 points
# Using cached path for 1608 to 1105
# Skipping path from 1608 to 1105 — insufficient points (2 points)
# Using cached path for 1105 to 1446
# Added path from 1105 to 1446 with 115 points
# Using cached path for 1446 to 1859
# Added path from 1446 to 1859 with 20 points
# Using cached path for 1859 to 0
# Added path from 1859 to 0 with 392 points
# Plotted path for vehicle 3 with 1584 coordinates
# Processing route for vehicle 4: ['0', 'SGMP', '24', 'SGGP', 'SGMI', '123', 'SGN2', 'SGNK', '128', 'SGSE', 'SGKC', '1084', 'SGJA', 'SGNO', 'SGJW', '171', '0']
# Using cached path for 0 to SGMP
# Added path from 0 to SGMP with 595 points
# Using cached path for SGMP to 24
# Added path from SGMP to 24 with 32 points
# Using cached path for 24 to SGGP
# Added path from 24 to SGGP with 10 points
# Using cached path for SGGP to SGMI
# Added path from SGGP to SGMI with 384 points
# Using cached path for SGMI to 123
# Added path from SGMI to 123 with 56 points
# Using cached path for 123 to SGN2
# Added path from 123 to SGN2 with 188 points
# Using cached path for SGN2 to SGNK
# Added path from SGN2 to SGNK with 63 points
# Using cached path for SGNK to 128
# Added path from SGNK to 128 with 214 points
# Using cached path for 128 to SGSE
# Added path from 128 to SGSE with 27 points
# Using cached path for SGSE to SGKC
# Added path from SGSE to SGKC with 119 points
# Using cached path for SGKC to 1084
# Skipping path from SGKC to 1084 — insufficient points (2 points)
# Using cached path for 1084 to SGJA
# Added path from 1084 to SGJA with 63 points
# Using cached path for SGJA to SGNO
# Added path from SGJA to SGNO with 132 points
# Using cached path for SGNO to SGJW
# Added path from SGNO to SGJW with 145 points
# Using cached path for SGJW to 171
# Added path from SGJW to 171 with 120 points
# Using cached path for 171 to 0
# Added path from 171 to 0 with 351 points
# Plotted path for vehicle 4 with 2499 coordinates
# Processing route for vehicle 5: ['0', 'SGSM', 'SCMU', '172', '1745', 'SCGT', 'SCWP', '1614', '1896', '1776', '1301', '1746', '1759', 'SCDR', '1545', 'SGKY', '0']
# Using cached path for 0 to SGSM
# Added path from 0 to SGSM with 335 points
# Using cached path for SGSM to SCMU
# Added path from SGSM to SCMU with 244 points
# Using cached path for SCMU to 172
# Added path from SCMU to 172 with 15 points
# Using cached path for 172 to 1745
# Added path from 172 to 1745 with 97 points
# Using cached path for 1745 to SCGT
# Added path from 1745 to SCGT with 43 points
# Using cached path for SCGT to SCWP
# Added path from SCGT to SCWP with 46 points
# Using cached path for SCWP to 1614
# Added path from SCWP to 1614 with 73 points
# Using cached path for 1614 to 1896
# Added path from 1614 to 1896 with 100 points
# Using cached path for 1896 to 1776
# Added path from 1896 to 1776 with 28 points
# Using cached path for 1776 to 1301
# Added path from 1776 to 1301 with 28 points
# Using cached path for 1301 to 1746
# Added path from 1301 to 1746 with 31 points
# Using cached path for 1746 to 1759
# Added path from 1746 to 1759 with 42 points
# Using cached path for 1759 to SCDR
# Added path from 1759 to SCDR with 81 points
# Using cached path for SCDR to 1545
# Added path from SCDR to 1545 with 74 points
# Using cached path for 1545 to SGKY
# Added path from 1545 to SGKY with 225 points
# Using cached path for SGKY to 0
# Added path from SGKY to 0 with 254 points
# Plotted path for vehicle 5 with 1716 coordinates
# Processing route for vehicle 6: ['0', 'SGMQ', '1355', '1548', '1549', 'SCAK', 'SCVJ', 'SCAR', 'SCPT', 'SCTH', 'SCBI', 'SLMN', '110', '14010', '1678', 'SCKX', '0']
# Using cached path for 0 to SGMQ
# Added path from 0 to SGMQ with 179 points
# Using cached path for SGMQ to 1355
# Added path from SGMQ to 1355 with 196 points
# Using cached path for 1355 to 1548
# Added path from 1355 to 1548 with 56 points
# Using cached path for 1548 to 1549
# Added path from 1548 to 1549 with 82 points
# Using cached path for 1549 to SCAK
# Added path from 1549 to SCAK with 319 points
# Using cached path for SCAK to SCVJ
# Added path from SCAK to SCVJ with 96 points
# Using cached path for SCVJ to SCAR
# Added path from SCVJ to SCAR with 48 points
# Using cached path for SCAR to SCPT
# Added path from SCAR to SCPT with 139 points
# Using cached path for SCPT to SCTH
# Added path from SCPT to SCTH with 13 points
# Using cached path for SCTH to SCBI
# Added path from SCTH to SCBI with 5 points
# Using cached path for SCBI to SLMN
# Skipping path from SCBI to SLMN — insufficient points (2 points)
# Using cached path for SLMN to 110
# Added path from SLMN to 110 with 149 points
# Using cached path for 110 to 14010
# Skipping path from 110 to 14010 — insufficient points (2 points)
# Using cached path for 14010 to 1678
# Added path from 14010 to 1678 with 78 points
# Using cached path for 1678 to SCKX
# Added path from 1678 to SCKX with 103 points
# Using cached path for SCKX to 0
# Added path from SCKX to 0 with 208 points
# Plotted path for vehicle 6 with 1671 coordinates
# Processing route for vehicle 7: ['0', 'SGKB', 'SGKG', '14', 'SGTY', '14015', 'SGKR', 'SGWA', '3', '14013', 'SGMH', 'SGRA', '150', 'SGGE', 'SGK5', 'SGEL', '0']
# Using cached path for 0 to SGKB
# Added path from 0 to SGKB with 106 points
# Using cached path for SGKB to SGKG
# Added path from SGKB to SGKG with 17 points
# Using cached path for SGKG to 14
# Added path from SGKG to 14 with 12 points
# Using cached path for 14 to SGTY
# Added path from 14 to SGTY with 21 points
# Using cached path for SGTY to 14015
# Added path from SGTY to 14015 with 131 points
# Using cached path for 14015 to SGKR
# Skipping path from 14015 to SGKR — insufficient points (2 points)
# Using cached path for SGKR to SGWA
# Added path from SGKR to SGWA with 15 points
# Using cached path for SGWA to 3
# Added path from SGWA to 3 with 8 points
# Using cached path for 3 to 14013
# Added path from 3 to 14013 with 215 points
# Using cached path for 14013 to SGMH
# Added path from 14013 to SGMH with 90 points
# Using cached path for SGMH to SGRA
# Added path from SGMH to SGRA with 75 points
# Using cached path for SGRA to 150
# Added path from SGRA to 150 with 39 points
# Using cached path for 150 to SGGE
# Added path from 150 to SGGE with 220 points
# Using cached path for SGGE to SGK5
# Added path from SGGE to SGK5 with 238 points
# Using cached path for SGK5 to SGEL
# Added path from SGK5 to SGEL with 178 points
# Using cached path for SGEL to 0
# Added path from SGEL to 0 with 215 points
# Plotted path for vehicle 7 with 1580 coordinates
# Saved 583 cached routes to ../data/csv/route_cache.csv
# Saved 329 unvisited nodes to output/csv/next_day_demand.csv for next-day processing.

# %%
visited_nodes, route_dict =controller.solve_multi_day(save_visualization=False)
# Out:
# Max Distance: [300, 300, 300, 300, 300, 300, 300, 300]
#
# Day 1 Routes (Penalty per unvisited demand unit: 100000 km):
# Route for vehicle 0:
#  0 -> 1109 -> SCHR -> 1305 -> 1650 -> 25 -> 1594 -> 1291 -> 1308 -> 1130 -> 1033 -> SCMD -> SCDP -> 1411 -> 1661 -> SCSL -> 0
# Distance of the route: 42 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 1:
#  0 -> SGEM -> 14011 -> 1676 -> 1419 -> SCTU -> 1017 -> 5 -> 1902 -> SCUP -> 1303 -> 14003 -> 1433 -> 1145 -> 1364 -> 1292 -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 2:
#  0 -> 1728 -> 1497 -> 1872 -> 1471 -> 1320 -> SCCR -> SCSJ -> SCRJ -> SCNW -> 14008 -> SCTB -> 1888 -> 1107 -> 1323 -> 1761 -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 3:
#  0 -> 1137 -> SCMY -> 1555 -> SCK7 -> 1108 -> SCKE -> 1818 -> 1005 -> 1672 -> SCCC -> 1826 -> 1608 -> 1105 -> 1446 -> 1859 -> 0
# Distance of the route: 39 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 4:
#  0 -> SGMP -> 24 -> SGGP -> SGMI -> 123 -> SGN2 -> SGNK -> 128 -> SGSE -> SGKC -> 1084 -> SGJA -> SGNO -> SGJW -> 171 -> 0
# Distance of the route: 76 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 5:
#  0 -> SGSM -> SCMU -> 172 -> 1745 -> SCGT -> SCWP -> 1614 -> 1896 -> 1776 -> 1301 -> 1746 -> 1759 -> SCDR -> 1545 -> SGKY -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 6:
#  0 -> SGMQ -> 1355 -> 1548 -> 1549 -> SCAK -> SCVJ -> SCAR -> SCPT -> SCTH -> SCBI -> SLMN -> 110 -> 14010 -> 1678 -> SCKX -> 0
# Distance of the route: 50 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 7:
#  0 -> SGKB -> SGKG -> 14 -> SGTY -> 14015 -> SGKR -> SGWA -> 3 -> 14013 -> SGMH -> SGRA -> 150 -> SGGE -> SGK5 -> SGEL -> 0
# Distance of the route: 37 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Maximum route distance for Day 1: 76 km
# Max Distance: [300, 300, 300, 300, 300, 300, 300, 300]
#
# Day 2 Routes (Penalty per unvisited demand unit: 100000 km):
# Route for vehicle 0:
#  0 -> 1109 -> SCHR -> 1305 -> 1650 -> 25 -> 1594 -> 1291 -> 1308 -> 1130 -> 1033 -> SCMD -> SCDP -> 1411 -> 1661 -> SCSL -> 0
# Distance of the route: 42 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 1:
#  0 -> SGEM -> 14011 -> 1676 -> 1419 -> SCTU -> 1017 -> 5 -> 1902 -> SCUP -> 1303 -> 14003 -> 1433 -> 1145 -> 1364 -> 1292 -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 2:
#  0 -> 1728 -> 1497 -> 1872 -> 1471 -> 1320 -> SCCR -> SCSJ -> SCRJ -> SCNW -> 14008 -> SCTB -> 1888 -> 1107 -> 1323 -> 1761 -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 3:
#  0 -> 1137 -> SCMY -> 1555 -> SCK7 -> 1108 -> SCKE -> 1818 -> 1005 -> 1672 -> SCCC -> 1826 -> 1608 -> 1105 -> 1446 -> 1859 -> 0
# Distance of the route: 39 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 4:
#  0 -> SGMP -> 24 -> SGGP -> SGMI -> 123 -> SGN2 -> SGNK -> 128 -> SGSE -> SGKC -> 1084 -> SGJA -> SGNO -> SGJW -> 171 -> 0
# Distance of the route: 76 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 5:
#  0 -> SGSM -> SCMU -> 172 -> 1745 -> SCGT -> SCWP -> 1614 -> 1896 -> 1776 -> 1301 -> 1746 -> 1759 -> SCDR -> 1545 -> SGKY -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 6:
#  0 -> SGMQ -> 1355 -> 1548 -> 1549 -> SCAK -> SCVJ -> SCAR -> SCPT -> SCTH -> SCBI -> SLMN -> 110 -> 14010 -> 1678 -> SCKX -> 0
# Distance of the route: 50 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 7:
#  0 -> SGKB -> SGKG -> 14 -> SGTY -> 14015 -> SGKR -> SGWA -> 3 -> 14013 -> SGMH -> SGRA -> 150 -> SGGE -> SGK5 -> SGEL -> 0
# Distance of the route: 37 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Maximum route distance for Day 2: 76 km
# Max Distance: [300, 300, 300, 300, 300, 300, 300, 300]
#
# Day 3 Routes (Penalty per unvisited demand unit: 100000 km):
# Route for vehicle 0:
#  0 -> 1109 -> SCHR -> 1305 -> 1650 -> 25 -> 1594 -> 1291 -> 1308 -> 1130 -> 1033 -> SCMD -> SCDP -> 1411 -> 1661 -> SCSL -> 0
# Distance of the route: 42 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 1:
#  0 -> SGEM -> 14011 -> 1676 -> 1419 -> SCTU -> 1017 -> 5 -> 1902 -> SCUP -> 1303 -> 14003 -> 1433 -> 1145 -> 1364 -> 1292 -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 2:
#  0 -> 1728 -> 1497 -> 1872 -> 1471 -> 1320 -> SCCR -> SCSJ -> SCRJ -> SCNW -> 14008 -> SCTB -> 1888 -> 1107 -> 1323 -> 1761 -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 3:
#  0 -> 1137 -> SCMY -> 1555 -> SCK7 -> 1108 -> SCKE -> 1818 -> 1005 -> 1672 -> SCCC -> 1826 -> 1608 -> 1105 -> 1446 -> 1859 -> 0
# Distance of the route: 39 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 4:
#  0 -> SGMP -> 24 -> SGGP -> SGMI -> 123 -> SGN2 -> SGNK -> 128 -> SGSE -> SGKC -> 1084 -> SGJA -> SGNO -> SGJW -> 171 -> 0
# Distance of the route: 76 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 5:
#  0 -> SGSM -> SCMU -> 172 -> 1745 -> SCGT -> SCWP -> 1614 -> 1896 -> 1776 -> 1301 -> 1746 -> 1759 -> SCDR -> 1545 -> SGKY -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 6:
#  0 -> SGMQ -> 1355 -> 1548 -> 1549 -> SCAK -> SCVJ -> SCAR -> SCPT -> SCTH -> SCBI -> SLMN -> 110 -> 14010 -> 1678 -> SCKX -> 0
# Distance of the route: 50 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 7:
#  0 -> SGKB -> SGKG -> 14 -> SGTY -> 14015 -> SGKR -> SGWA -> 3 -> 14013 -> SGMH -> SGRA -> 150 -> SGGE -> SGK5 -> SGEL -> 0
# Distance of the route: 37 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Maximum route distance for Day 3: 76 km
# Max Distance: [300, 300, 300, 300, 300, 300, 300, 300]
#
# Day 4 Routes (Penalty per unvisited demand unit: 100000 km):
# Route for vehicle 0:
#  0 -> 1109 -> SCHR -> 1305 -> 1650 -> 25 -> 1594 -> 1291 -> 1308 -> 1130 -> 1033 -> SCMD -> SCDP -> 1411 -> 1661 -> SCSL -> 0
# Distance of the route: 42 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 1:
#  0 -> SGEM -> 14011 -> 1676 -> 1419 -> SCTU -> 1017 -> 5 -> 1902 -> SCUP -> 1303 -> 14003 -> 1433 -> 1145 -> 1364 -> 1292 -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 2:
#  0 -> 1728 -> 1497 -> 1872 -> 1471 -> 1320 -> SCCR -> SCSJ -> SCRJ -> SCNW -> 14008 -> SCTB -> 1888 -> 1107 -> 1323 -> 1761 -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 3:
#  0 -> 1137 -> SCMY -> 1555 -> SCK7 -> 1108 -> SCKE -> 1818 -> 1005 -> 1672 -> SCCC -> 1826 -> 1608 -> 1105 -> 1446 -> 1859 -> 0
# Distance of the route: 39 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 4:
#  0 -> SGMP -> 24 -> SGGP -> SGMI -> 123 -> SGN2 -> SGNK -> 128 -> SGSE -> SGKC -> 1084 -> SGJA -> SGNO -> SGJW -> 171 -> 0
# Distance of the route: 76 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 5:
#  0 -> SGSM -> SCMU -> 172 -> 1745 -> SCGT -> SCWP -> 1614 -> 1896 -> 1776 -> 1301 -> 1746 -> 1759 -> SCDR -> 1545 -> SGKY -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 6:
#  0 -> SGMQ -> 1355 -> 1548 -> 1549 -> SCAK -> SCVJ -> SCAR -> SCPT -> SCTH -> SCBI -> SLMN -> 110 -> 14010 -> 1678 -> SCKX -> 0
# Distance of the route: 50 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 7:
#  0 -> SGKB -> SGKG -> 14 -> SGTY -> 14015 -> SGKR -> SGWA -> 3 -> 14013 -> SGMH -> SGRA -> 150 -> SGGE -> SGK5 -> SGEL -> 0
# Distance of the route: 37 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Maximum route distance for Day 4: 76 km
# Max Distance: [300, 300, 300, 300, 300, 300, 300, 300]
#
# Day 5 Routes (Penalty per unvisited demand unit: 100000 km):
# Route for vehicle 0:
#  0 -> 1109 -> SCHR -> 1305 -> 1650 -> 25 -> 1594 -> 1291 -> 1308 -> 1130 -> 1033 -> SCMD -> SCDP -> 1411 -> 1661 -> SCSL -> 0
# Distance of the route: 42 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 1:
#  0 -> SGEM -> 14011 -> 1676 -> 1419 -> SCTU -> 1017 -> 5 -> 1902 -> SCUP -> 1303 -> 14003 -> 1433 -> 1145 -> 1364 -> 1292 -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 2:
#  0 -> 1728 -> 1497 -> 1872 -> 1471 -> 1320 -> SCCR -> SCSJ -> SCRJ -> SCNW -> 14008 -> SCTB -> 1888 -> 1107 -> 1323 -> 1761 -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 3:
#  0 -> 1137 -> SCMY -> 1555 -> SCK7 -> 1108 -> SCKE -> 1818 -> 1005 -> 1672 -> SCCC -> 1826 -> 1608 -> 1105 -> 1446 -> 1859 -> 0
# Distance of the route: 39 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 4:
#  0 -> SGMP -> 24 -> SGGP -> SGMI -> 123 -> SGN2 -> SGNK -> 128 -> SGSE -> SGKC -> 1084 -> SGJA -> SGNO -> SGJW -> 171 -> 0
# Distance of the route: 76 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 5:
#  0 -> SGSM -> SCMU -> 172 -> 1745 -> SCGT -> SCWP -> 1614 -> 1896 -> 1776 -> 1301 -> 1746 -> 1759 -> SCDR -> 1545 -> SGKY -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 6:
#  0 -> SGMQ -> 1355 -> 1548 -> 1549 -> SCAK -> SCVJ -> SCAR -> SCPT -> SCTH -> SCBI -> SLMN -> 110 -> 14010 -> 1678 -> SCKX -> 0
# Distance of the route: 50 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 7:
#  0 -> SGKB -> SGKG -> 14 -> SGTY -> 14015 -> SGKR -> SGWA -> 3 -> 14013 -> SGMH -> SGRA -> 150 -> SGGE -> SGK5 -> SGEL -> 0
# Distance of the route: 37 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Maximum route distance for Day 5: 76 km
# Max Distance: [300, 300, 300, 300, 300, 300, 300, 300]
#
# Day 6 Routes (Penalty per unvisited demand unit: 100000 km):
# Route for vehicle 0:
#  0 -> SCSL -> 1017 -> 1411 -> SCDP -> SCMD -> 1033 -> 1130 -> 1308 -> 1291 -> 1594 -> 25 -> 1650 -> 1305 -> SCHR -> SGEM -> 0
# Distance of the route: 41 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 1:
#  0 -> 1292 -> 1433 -> 1145 -> 14003 -> 1303 -> SCUP -> 1902 -> 5 -> 1661 -> 1676 -> 14011 -> 1419 -> SCTB -> SCTU -> 1364 -> 0
# Distance of the route: 37 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 2:
#  0 -> 1728 -> 1497 -> 1872 -> 1471 -> 1320 -> SCCR -> SCSJ -> SCRJ -> SCNW -> 14008 -> 1109 -> 1888 -> 1107 -> 1323 -> 1761 -> 0
# Distance of the route: 37 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 3:
#  0 -> 1137 -> SCMY -> 1555 -> SCK7 -> 1108 -> SCKE -> 1818 -> 1005 -> 1672 -> SCCC -> 1826 -> 1608 -> 1105 -> 1446 -> 1859 -> 0
# Distance of the route: 39 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 4:
#  0 -> SGMP -> 24 -> SGGP -> SGMI -> 123 -> SGN2 -> SGNK -> 128 -> SGSE -> SGKC -> 1084 -> SGJA -> SGNO -> SGJW -> 171 -> 0
# Distance of the route: 76 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 5:
#  0 -> SGSM -> SCMU -> 172 -> 1745 -> SCGT -> SCWP -> 1614 -> 1896 -> 1776 -> 1301 -> 1746 -> 1759 -> SCDR -> 1545 -> SGKY -> 0
# Distance of the route: 36 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 6:
#  0 -> SGMQ -> 1355 -> 1548 -> 1549 -> SCAK -> SCVJ -> SCAR -> SCPT -> SCTH -> SCBI -> SLMN -> 110 -> 14010 -> 1678 -> SCKX -> 0
# Distance of the route: 50 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Route for vehicle 7:
#  0 -> SGKB -> SGKG -> 14 -> SGTY -> 14015 -> SGKR -> SGWA -> 3 -> 14013 -> SGMH -> SGRA -> 150 -> SGGE -> SGK5 -> SGEL -> 0
# Distance of the route: 37 km
# Within limit: Yes (Max: 300 km)
# Stops visited: 15/15
#
# Maximum route distance for Day 6: 76 km
#
# === Day 1 ===
# Route Summary:
#     Vehicle    Stops      Distance        Within Limit
# -------------------------------------------------------
#     0          15         42         km   Yes
#     1          15         36         km   Yes
#     2          15         36         km   Yes
#     3          15         39         km   Yes
#     4          15         76         km   Yes
#     5          15         36         km   Yes
#     6          15         50         km   Yes
#     7          15         37         km   Yes
# -------------------------------------------------------
#     Total      120        352        km
# Summary saved to output/summaries/day_1_summary.txt
# Route details saved to output/csv/day_1_routes.csv
#
# === Day 2 ===
# Route Summary:
#     Vehicle    Stops      Distance        Within Limit
# -------------------------------------------------------
#     0          15         42         km   Yes
#     1          15         36         km   Yes
#     2          15         36         km   Yes
#     3          15         39         km   Yes
#     4          15         76         km   Yes
#     5          15         36         km   Yes
#     6          15         50         km   Yes
#     7          15         37         km   Yes
# -------------------------------------------------------
#     Total      120        352        km
# Summary saved to output/summaries/day_2_summary.txt
# Route details saved to output/csv/day_2_routes.csv
#
# === Day 3 ===
# Route Summary:
#     Vehicle    Stops      Distance        Within Limit
# -------------------------------------------------------
#     0          15         42         km   Yes
#     1          15         36         km   Yes
#     2          15         36         km   Yes
#     3          15         39         km   Yes
#     4          15         76         km   Yes
#     5          15         36         km   Yes
#     6          15         50         km   Yes
#     7          15         37         km   Yes
# -------------------------------------------------------
#     Total      120        352        km
# Summary saved to output/summaries/day_3_summary.txt
# Route details saved to output/csv/day_3_routes.csv
#
# === Day 4 ===
# Route Summary:
#     Vehicle    Stops      Distance        Within Limit
# -------------------------------------------------------
#     0          15         42         km   Yes
#     1          15         36         km   Yes
#     2          15         36         km   Yes
#     3          15         39         km   Yes
#     4          15         76         km   Yes
#     5          15         36         km   Yes
#     6          15         50         km   Yes
#     7          15         37         km   Yes
# -------------------------------------------------------
#     Total      120        352        km
# Summary saved to output/summaries/day_4_summary.txt
# Route details saved to output/csv/day_4_routes.csv
#
# === Day 5 ===
# Route Summary:
#     Vehicle    Stops      Distance        Within Limit
# -------------------------------------------------------
#     0          15         42         km   Yes
#     1          15         36         km   Yes
#     2          15         36         km   Yes
#     3          15         39         km   Yes
#     4          15         76         km   Yes
#     5          15         36         km   Yes
#     6          15         50         km   Yes
#     7          15         37         km   Yes
# -------------------------------------------------------
#     Total      120        352        km
# Summary saved to output/summaries/day_5_summary.txt
# Route details saved to output/csv/day_5_routes.csv
#
# === Day 6 ===
# Route Summary:
#     Vehicle    Stops      Distance        Within Limit
# -------------------------------------------------------
#     0          15         41         km   Yes
#     1          15         37         km   Yes
#     2          15         37         km   Yes
#     3          15         39         km   Yes
#     4          15         76         km   Yes
#     5          15         36         km   Yes
#     6          15         50         km   Yes
#     7          15         37         km   Yes
# -------------------------------------------------------
#     Total      120        353        km
# Summary saved to output/summaries/day_6_summary.txt
# Route details saved to output/csv/day_6_routes.csv
# Multi-day summary saved to output/summaries/multi_day_summary.txt
# Saved 329 unvisited nodes to output/csv/next_day_demand.csv for next-day processing.
