# %%
import pandas as pd
import requests
import numpy as np
import time
import folium
import matplotlib.pyplot as plt
import json

# %%
# Load existing data if available
try:
    distance_df = pd.read_csv("data/osrm_distance_matrix.csv", index_col=0)
    distance_matrix = distance_df.values
    print(distance_df.shape)
    duration_df = pd.read_csv("data/osrm_duration_matrix.csv", index_col=0)
    duration_matrix = duration_df.values
    existing_codes = duration_df.index.tolist()  # Get existing codes from the index
except FileNotFoundError:
    print("No previous data found. Starting fresh.")
    distance_matrix = np.zeros((0, 0))  # Initialize empty matrices
    duration_matrix = np.zeros((0, 0))
    existing_codes = []
# Out:
# (651, 651)

# %%
# Load new data from CSV
data = pd.read_csv('data/07-03-2025-PO.csv')
data = data.dropna(subset=['CODE'])


if data['CODE'].dtype in ['float', 'int']:
    data['CODE'] = data['CODE'].astype(int)
    data['CODE'] = data['CODE'].astype(str)
    print('Converting to Object')

# %%
# #Load new data from CSV
data = pd.read_csv('data/master_gps.csv')
data = data.dropna(subset=['CODE'])

# %%
SMAK_KADAWATHA = (7.0038321,79.9394804)

smak_data = {
    "CODE":'0',
    "LOCATION":"SMAK",
    "ADDRESS":"Smak, Kadawatha, Western Province, Sri Lanka",
    "LATITUDE":SMAK_KADAWATHA[0],
    "LONGITUDE":SMAK_KADAWATHA[1],
    "BRAND":"SMAK"
}


data = pd.concat(
    [
        pd.DataFrame(smak_data, index=[0]),
        data
    ],
    ignore_index=True
)

# %%
# Extract locations and codes from new data
new_data = data[['CODE', 'LATITUDE', 'LONGITUDE']].drop_duplicates(subset=['CODE'])
new_codes = new_data['CODE'].tolist()
new_locations = [(row['LATITUDE'], row['LONGITUDE']) for _, row in new_data.iterrows()]

# %%
new_data.shape, data.shape
# Out:
# ((651, 3), (651, 6))

# %%
data[data['CODE']=='0']
# Out:
#   CODE LOCATION                                       ADDRESS  LATITUDE  \
# 0    0     SMAK  Smak, Kadawatha, Western Province, Sri Lanka  7.003832
#
#    LONGITUDE BRAND
# 0   79.93948  SMAK

# %%
# Identify codes that are not in the existing matrix
codes_to_add = [code for code in new_codes if code not in existing_codes]
locations_to_add = [loc for i, loc in enumerate(new_locations) if new_codes[i] in codes_to_add]

# %%
len(codes_to_add), len(locations_to_add)
# Out:
# (0, 0)

# %%
master_gps = pd.read_csv('data/master_gps.csv')

# Update master_gps with new entries
new_gps_data = data[data['CODE'].isin(codes_to_add)][['CODE', 'LOCATION' ,'ADDRESS', 'LATITUDE', 'LONGITUDE', 'BRAND']]
master_gps = pd.concat([master_gps, new_gps_data], ignore_index=True)
master_gps = master_gps.drop_duplicates(subset=['CODE'], keep='first')
print(master_gps.shape)
# master_gps.to_csv('data/master_gps.csv', index=False)
# Out:
# (650, 6)

# %%
master_data = pd.concat(
    [
        pd.DataFrame(smak_data, index=[0]),
        master_gps
    ],
    ignore_index=True
)

# %%
existing_locations = list(zip(master_data['LATITUDE'], master_data['LONGITUDE']))

# %%
len(existing_locations), len(codes_to_add)
# Out:
# (651, 0)

# %%
def get_osrm_data(origin, destination):
    """
    Get the distance between two coordinates using OSRM API.
    :param origin: (latitude, longitude)
    :param destination: (latitude, longitude)
    :return: Distance in meters
    """
    osrm_base_url = "http://router.project-osrm.org/route/v1/car"
    url = f"{osrm_base_url}/{origin[1]},{origin[0]};{destination[1]},{destination[0]}?overview=full&geometries=geojson"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        if "routes" in data and len(data["routes"]) > 0:
            path_cords = data["routes"][0]["geometry"]["coordinates"]
            distance = data["routes"][0]["distance"] / 1000
            duration = data["routes"][0]["duration"]/ 60
            return path_cords, distance, duration
        
    return None, np.inf, np.inf

# %%
len(existing_locations), len(locations_to_add)
# Out:
# (651, 0)

# %%
len(existing_codes), len(codes_to_add)
# Out:
# (651, 0)

# %%
len(codes_to_add), len(locations_to_add)
# Out:
# (0, 0)

# %%
if locations_to_add is not None:
    locations = existing_locations
    # locations.extend(locations_to_add)
    codes = existing_codes + codes_to_add
    num_codes = len(codes)
    print(len(locations))
    print(len(codes))
    # Resize matrices if new locations are added
    if distance_matrix.shape[0] < num_codes:
        old_size = distance_matrix.shape[0]
        new_distance_matrix = np.zeros((num_codes, num_codes))
        new_duration_matrix = np.zeros((num_codes, num_codes))
        
        if old_size > 0:
            new_distance_matrix[:old_size, :old_size] = distance_matrix
            new_duration_matrix[:old_size, :old_size] = duration_matrix
        
        distance_matrix = new_distance_matrix
        duration_matrix = new_duration_matrix
        

    # route_data = []
    for i in range(num_codes):
        for j in range(i + 1, num_codes):
            if distance_matrix[i][j] == 0 or np.isinf(distance_matrix[i][j]):
                origin = locations[i]
                destination = locations[j]

                path_cords, distance, duration = get_osrm_data(origin, destination)

                distance_matrix[i][j] = round(distance, 2)
                distance_matrix[j][i] = round(distance, 2)
                
                duration_matrix[i][j] = round(duration, 2)
                duration_matrix[j][i] = round(duration, 2)
                time.sleep(0.00001)
        print(f'{i} th row proceeded')

        if i % 5 == 0:
            distance_df = pd.DataFrame(distance_matrix, index=codes, columns=codes)
            distance_df.to_csv("data/osrm_distance_matrix.csv")
            duration_df = pd.DataFrame(duration_matrix, index=codes, columns=codes)
            duration_df.to_csv("data/osrm_duration_matrix.csv")
            
            # with open("data/osrm_route_data.json", "w") as json_file:
            #     json.dump(route_data, json_file, indent=4)

    # Final save for matrices and route data
    distance_df = pd.DataFrame(distance_matrix, index=codes, columns=codes)
    distance_df.to_csv("data/osrm_distance_matrix.csv")
    duration_df = pd.DataFrame(duration_matrix, index=codes, columns=codes)
    duration_df.to_csv("data/osrm_duration_matrix.csv")
    # with open("data/osrm_route_data.json", "w") as json_file:
    #     json.dump(route_data, json_file, indent=4)
    print(f"Added {len(locations_to_add)} new unique locations with codes: {codes_to_add}")
    print("Master GPS file updated.")       
else:
    print("No location to add")
# Out:
# 651
# 651
# 0 th row proceeded
# 1 th row proceeded
# 2 th row proceeded
# 3 th row proceeded
# 4 th row proceeded
# 5 th row proceeded
# 6 th row proceeded
# 7 th row proceeded
# 8 th row proceeded
# 9 th row proceeded
# 10 th row proceeded
# 11 th row proceeded
# 12 th row proceeded
# 13 th row proceeded
# 14 th row proceeded
# 15 th row proceeded
# 16 th row proceeded
# 17 th row proceeded
# 18 th row proceeded
# 19 th row proceeded
# 20 th row proceeded
# 21 th row proceeded
# 22 th row proceeded
# 23 th row proceeded
# 24 th row proceeded
# 25 th row proceeded
# 26 th row proceeded
# 27 th row proceeded
# 28 th row proceeded
# 29 th row proceeded
# 30 th row proceeded
# 31 th row proceeded
# 32 th row proceeded
# 33 th row proceeded
# 34 th row proceeded
# 35 th row proceeded
# 36 th row proceeded
# 37 th row proceeded
# 38 th row proceeded
# 39 th row proceeded
# 40 th row proceeded
# 41 th row proceeded
# 42 th row proceeded
# 43 th row proceeded
# 44 th row proceeded
# 45 th row proceeded
# 46 th row proceeded
# 47 th row proceeded
# 48 th row proceeded
# 49 th row proceeded
# 50 th row proceeded
# 51 th row proceeded
# 52 th row proceeded
# 53 th row proceeded
# 54 th row proceeded
# 55 th row proceeded
# 56 th row proceeded
# 57 th row proceeded
# 58 th row proceeded
# 59 th row proceeded
# 60 th row proceeded
# 61 th row proceeded
# 62 th row proceeded
# 63 th row proceeded
# 64 th row proceeded
# 65 th row proceeded
# 66 th row proceeded
# 67 th row proceeded
# 68 th row proceeded
# 69 th row proceeded
# 70 th row proceeded
# 71 th row proceeded
# 72 th row proceeded
# 73 th row proceeded
# 74 th row proceeded
# 75 th row proceeded
# 76 th row proceeded
# 77 th row proceeded
# 78 th row proceeded
# 79 th row proceeded
# 80 th row proceeded
# 81 th row proceeded
# 82 th row proceeded
# 83 th row proceeded
# 84 th row proceeded
# 85 th row proceeded
# 86 th row proceeded
# 87 th row proceeded
# 88 th row proceeded
# 89 th row proceeded
# 90 th row proceeded
# 91 th row proceeded
# 92 th row proceeded
# 93 th row proceeded
# 94 th row proceeded
# 95 th row proceeded
# 96 th row proceeded
# 97 th row proceeded
# 98 th row proceeded
# 99 th row proceeded
# 100 th row proceeded
# 101 th row proceeded
# 102 th row proceeded
# 103 th row proceeded
# 104 th row proceeded
# 105 th row proceeded
# 106 th row proceeded
# 107 th row proceeded
# 108 th row proceeded
# 109 th row proceeded
# 110 th row proceeded
# 111 th row proceeded
# 112 th row proceeded
# 113 th row proceeded
# 114 th row proceeded
# 115 th row proceeded
# 116 th row proceeded
# 117 th row proceeded
# 118 th row proceeded
# 119 th row proceeded
# 120 th row proceeded
# 121 th row proceeded
# 122 th row proceeded
# 123 th row proceeded
# 124 th row proceeded
# 125 th row proceeded
# 126 th row proceeded
# 127 th row proceeded
# 128 th row proceeded
# 129 th row proceeded
# 130 th row proceeded
# 131 th row proceeded
# 132 th row proceeded
# 133 th row proceeded
# 134 th row proceeded
# 135 th row proceeded
# 136 th row proceeded
# 137 th row proceeded
# 138 th row proceeded
# 139 th row proceeded
# 140 th row proceeded
# 141 th row proceeded
# 142 th row proceeded
# 143 th row proceeded
# 144 th row proceeded
# 145 th row proceeded
# 146 th row proceeded
# 147 th row proceeded
# 148 th row proceeded
# 149 th row proceeded
# 150 th row proceeded
# 151 th row proceeded
# 152 th row proceeded
# 153 th row proceeded
# 154 th row proceeded
# 155 th row proceeded
# 156 th row proceeded
# 157 th row proceeded
# 158 th row proceeded
# 159 th row proceeded
# 160 th row proceeded
# 161 th row proceeded
# 162 th row proceeded
# 163 th row proceeded
# 164 th row proceeded
# 165 th row proceeded
# 166 th row proceeded
# 167 th row proceeded
# 168 th row proceeded
# 169 th row proceeded
# 170 th row proceeded
# 171 th row proceeded
# 172 th row proceeded
# 173 th row proceeded
# 174 th row proceeded
# 175 th row proceeded
# 176 th row proceeded
# 177 th row proceeded
# 178 th row proceeded
# 179 th row proceeded
# 180 th row proceeded
# 181 th row proceeded
# 182 th row proceeded
# 183 th row proceeded
# 184 th row proceeded
# 185 th row proceeded
# 186 th row proceeded
# 187 th row proceeded
# 188 th row proceeded
# 189 th row proceeded
# 190 th row proceeded
# 191 th row proceeded
# 192 th row proceeded
# 193 th row proceeded
# 194 th row proceeded
# 195 th row proceeded
# 196 th row proceeded
# 197 th row proceeded
# 198 th row proceeded
# 199 th row proceeded
# 200 th row proceeded
# 201 th row proceeded
# 202 th row proceeded
# 203 th row proceeded
# 204 th row proceeded
# 205 th row proceeded
# 206 th row proceeded
# 207 th row proceeded
# 208 th row proceeded
# 209 th row proceeded
# 210 th row proceeded
# 211 th row proceeded
# 212 th row proceeded
# 213 th row proceeded
# 214 th row proceeded
# 215 th row proceeded
# 216 th row proceeded
# 217 th row proceeded
# 218 th row proceeded
# 219 th row proceeded
# 220 th row proceeded
# 221 th row proceeded
# 222 th row proceeded
# 223 th row proceeded
# 224 th row proceeded
# 225 th row proceeded
# 226 th row proceeded
# 227 th row proceeded
# 228 th row proceeded
# 229 th row proceeded
# 230 th row proceeded
# 231 th row proceeded
# 232 th row proceeded
# 233 th row proceeded
# 234 th row proceeded
# 235 th row proceeded
# 236 th row proceeded
# 237 th row proceeded
# 238 th row proceeded
# 239 th row proceeded
# 240 th row proceeded
# 241 th row proceeded
# 242 th row proceeded
# 243 th row proceeded
# 244 th row proceeded
# 245 th row proceeded
# 246 th row proceeded
# 247 th row proceeded
# 248 th row proceeded
# 249 th row proceeded
# 250 th row proceeded
# 251 th row proceeded
# 252 th row proceeded
# 253 th row proceeded
# 254 th row proceeded
# 255 th row proceeded
# 256 th row proceeded
# 257 th row proceeded
# 258 th row proceeded
# 259 th row proceeded
# 260 th row proceeded
# 261 th row proceeded
# 262 th row proceeded
# 263 th row proceeded
# 264 th row proceeded
# 265 th row proceeded
# 266 th row proceeded
# 267 th row proceeded
# 268 th row proceeded
# 269 th row proceeded
# 270 th row proceeded
# 271 th row proceeded
# 272 th row proceeded
# 273 th row proceeded
# 274 th row proceeded
# 275 th row proceeded
# 276 th row proceeded
# 277 th row proceeded
# 278 th row proceeded
# 279 th row proceeded
# 280 th row proceeded
# 281 th row proceeded
# 282 th row proceeded
# 283 th row proceeded
# 284 th row proceeded
# 285 th row proceeded
# 286 th row proceeded
# 287 th row proceeded
# 288 th row proceeded
# 289 th row proceeded
# 290 th row proceeded
# 291 th row proceeded
# 292 th row proceeded
# 293 th row proceeded
# 294 th row proceeded
# 295 th row proceeded
# 296 th row proceeded
# 297 th row proceeded
# 298 th row proceeded
# 299 th row proceeded
# 300 th row proceeded
# 301 th row proceeded
# 302 th row proceeded
# 303 th row proceeded
# 304 th row proceeded
# 305 th row proceeded
# 306 th row proceeded
# 307 th row proceeded
# 308 th row proceeded
# 309 th row proceeded
# 310 th row proceeded
# 311 th row proceeded
# 312 th row proceeded
# 313 th row proceeded
# 314 th row proceeded
# 315 th row proceeded
# 316 th row proceeded
# 317 th row proceeded
# 318 th row proceeded
# 319 th row proceeded
# 320 th row proceeded
# 321 th row proceeded
# 322 th row proceeded
# 323 th row proceeded
# 324 th row proceeded
# 325 th row proceeded
# 326 th row proceeded
# 327 th row proceeded
# 328 th row proceeded
# 329 th row proceeded
# 330 th row proceeded
# 331 th row proceeded
# 332 th row proceeded
# 333 th row proceeded
# 334 th row proceeded
# 335 th row proceeded
# 336 th row proceeded
# 337 th row proceeded
# 338 th row proceeded
# 339 th row proceeded
# 340 th row proceeded
# 341 th row proceeded
# 342 th row proceeded
# 343 th row proceeded
# 344 th row proceeded
# 345 th row proceeded
# 346 th row proceeded
# 347 th row proceeded
# 348 th row proceeded
# 349 th row proceeded
# 350 th row proceeded
# 351 th row proceeded
# 352 th row proceeded
# 353 th row proceeded
# 354 th row proceeded
# 355 th row proceeded
# 356 th row proceeded
# 357 th row proceeded
# 358 th row proceeded
# 359 th row proceeded
# 360 th row proceeded
# 361 th row proceeded
# 362 th row proceeded
# 363 th row proceeded
# 364 th row proceeded
# 365 th row proceeded
# 366 th row proceeded
# 367 th row proceeded
# 368 th row proceeded
# 369 th row proceeded
# 370 th row proceeded
# 371 th row proceeded
# 372 th row proceeded
# 373 th row proceeded
# 374 th row proceeded
# 375 th row proceeded
# 376 th row proceeded
# 377 th row proceeded
# 378 th row proceeded
# 379 th row proceeded
# 380 th row proceeded
# 381 th row proceeded
# 382 th row proceeded
# 383 th row proceeded
# 384 th row proceeded
# 385 th row proceeded
# 386 th row proceeded
# 387 th row proceeded
# 388 th row proceeded
# 389 th row proceeded
# 390 th row proceeded
# 391 th row proceeded
# 392 th row proceeded
# 393 th row proceeded
# 394 th row proceeded
# 395 th row proceeded
# 396 th row proceeded
# 397 th row proceeded
# 398 th row proceeded
# 399 th row proceeded
# 400 th row proceeded
# 401 th row proceeded
# 402 th row proceeded
# 403 th row proceeded
# 404 th row proceeded
# 405 th row proceeded
# 406 th row proceeded
# 407 th row proceeded
# 408 th row proceeded
# 409 th row proceeded
# 410 th row proceeded
# 411 th row proceeded
# 412 th row proceeded
# 413 th row proceeded
# 414 th row proceeded
# 415 th row proceeded
# 416 th row proceeded
# 417 th row proceeded
# 418 th row proceeded
# 419 th row proceeded
# 420 th row proceeded
# 421 th row proceeded
# 422 th row proceeded
# 423 th row proceeded
# 424 th row proceeded
# 425 th row proceeded
# 426 th row proceeded
# 427 th row proceeded
# 428 th row proceeded
# 429 th row proceeded
# 430 th row proceeded
# 431 th row proceeded
# 432 th row proceeded
# 433 th row proceeded
# 434 th row proceeded
# 435 th row proceeded
# 436 th row proceeded
# 437 th row proceeded
# 438 th row proceeded
# 439 th row proceeded
# 440 th row proceeded
# 441 th row proceeded
# 442 th row proceeded
# 443 th row proceeded
# 444 th row proceeded
# 445 th row proceeded
# 446 th row proceeded
# 447 th row proceeded
# 448 th row proceeded
# 449 th row proceeded
# 450 th row proceeded
# 451 th row proceeded
# 452 th row proceeded
# 453 th row proceeded
# 454 th row proceeded
# 455 th row proceeded
# 456 th row proceeded
# 457 th row proceeded
# 458 th row proceeded
# 459 th row proceeded
# 460 th row proceeded
# 461 th row proceeded
# 462 th row proceeded
# 463 th row proceeded
# 464 th row proceeded
# 465 th row proceeded
# 466 th row proceeded
# 467 th row proceeded
# 468 th row proceeded
# 469 th row proceeded
# 470 th row proceeded
# 471 th row proceeded
# 472 th row proceeded
# 473 th row proceeded
# 474 th row proceeded
# 475 th row proceeded
# 476 th row proceeded
# 477 th row proceeded
# 478 th row proceeded
# 479 th row proceeded
# 480 th row proceeded
# 481 th row proceeded
# 482 th row proceeded
# 483 th row proceeded
# 484 th row proceeded
# 485 th row proceeded
# 486 th row proceeded
# 487 th row proceeded
# 488 th row proceeded
# 489 th row proceeded
# 490 th row proceeded
# 491 th row proceeded
# 492 th row proceeded
# 493 th row proceeded
# 494 th row proceeded
# 495 th row proceeded
# 496 th row proceeded
# 497 th row proceeded
# 498 th row proceeded
# 499 th row proceeded
# 500 th row proceeded
# 501 th row proceeded
# 502 th row proceeded
# 503 th row proceeded
# 504 th row proceeded
# 505 th row proceeded
# 506 th row proceeded
# 507 th row proceeded
# 508 th row proceeded
# 509 th row proceeded
# 510 th row proceeded
# 511 th row proceeded
# 512 th row proceeded
# 513 th row proceeded
# 514 th row proceeded
# 515 th row proceeded
# 516 th row proceeded
# 517 th row proceeded
# 518 th row proceeded
# 519 th row proceeded
# 520 th row proceeded
# 521 th row proceeded
# 522 th row proceeded
# 523 th row proceeded
# 524 th row proceeded
# 525 th row proceeded
# 526 th row proceeded
# 527 th row proceeded
# 528 th row proceeded
# 529 th row proceeded
# 530 th row proceeded
# 531 th row proceeded
# 532 th row proceeded
# 533 th row proceeded
# 534 th row proceeded
# 535 th row proceeded
# 536 th row proceeded
# 537 th row proceeded
# 538 th row proceeded
# 539 th row proceeded
# 540 th row proceeded
# 541 th row proceeded
# 542 th row proceeded
# 543 th row proceeded
# 544 th row proceeded
# 545 th row proceeded
# 546 th row proceeded
# 547 th row proceeded
# 548 th row proceeded
# 549 th row proceeded
# 550 th row proceeded
# 551 th row proceeded
# 552 th row proceeded
# 553 th row proceeded
# 554 th row proceeded
# 555 th row proceeded
# 556 th row proceeded
# 557 th row proceeded
# 558 th row proceeded
# 559 th row proceeded
# 560 th row proceeded
# 561 th row proceeded
# 562 th row proceeded
# 563 th row proceeded
# 564 th row proceeded
# 565 th row proceeded
# 566 th row proceeded
# 567 th row proceeded
# 568 th row proceeded
# 569 th row proceeded
# 570 th row proceeded
# 571 th row proceeded
# 572 th row proceeded
# 573 th row proceeded
# 574 th row proceeded
# 575 th row proceeded
# 576 th row proceeded
# 577 th row proceeded
# 578 th row proceeded
# 579 th row proceeded
# 580 th row proceeded
# 581 th row proceeded
# 582 th row proceeded
# 583 th row proceeded
# 584 th row proceeded
# 585 th row proceeded
# 586 th row proceeded
# 587 th row proceeded
# 588 th row proceeded
# 589 th row proceeded
# 590 th row proceeded
# 591 th row proceeded
# 592 th row proceeded
# 593 th row proceeded
# 594 th row proceeded
# 595 th row proceeded
# 596 th row proceeded
# 597 th row proceeded
# 598 th row proceeded
# 599 th row proceeded
# 600 th row proceeded
# 601 th row proceeded
# 602 th row proceeded
# 603 th row proceeded
# 604 th row proceeded
# 605 th row proceeded
# 606 th row proceeded
# 607 th row proceeded
# 608 th row proceeded
# 609 th row proceeded
# 610 th row proceeded
# 611 th row proceeded
# 612 th row proceeded
# 613 th row proceeded
# 614 th row proceeded
# 615 th row proceeded
# 616 th row proceeded
# 617 th row proceeded
# 618 th row proceeded
# 619 th row proceeded
# 620 th row proceeded
# 621 th row proceeded
# 622 th row proceeded
# 623 th row proceeded
# 624 th row proceeded
# 625 th row proceeded
# 626 th row proceeded
# 627 th row proceeded
# 628 th row proceeded
# 629 th row proceeded
# 630 th row proceeded
# 631 th row proceeded
# 632 th row proceeded
# 633 th row proceeded
# 634 th row proceeded
# 635 th row proceeded
# 636 th row proceeded
# 637 th row proceeded
# 638 th row proceeded
# 639 th row proceeded
# 640 th row proceeded
# 641 th row proceeded
# 642 th row proceeded
# 643 th row proceeded
# 644 th row proceeded
# 645 th row proceeded
# 646 th row proceeded
# 647 th row proceeded
# 648 th row proceeded
# 649 th row proceeded
# 650 th row proceeded
# Added 0 new unique locations with codes: []
# Master GPS file updated.

# %%
lis = [1,2,3]
set(lis)
# Out:
# {1, 2, 3}

# %%
{1,2,3,4,5} - {1,2,3}
# Out:
# {4, 5}
