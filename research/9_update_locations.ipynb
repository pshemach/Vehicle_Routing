# %%
import pandas as pd
import requests

# %%
def get_gcp_gps(address):
    key = 'AIzaSyACpYMHnmkd8DWxWS3KTJ70EeKIRYN2xHM'
    # Construct the URL
    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={address}&key={key}"

    # Send the request
    response = requests.get(url)

    # Parse the JSON response
    if response.status_code == 200:
        data = response.json()
        if data['status'] == 'OK':
            location = data['results'][0]['geometry']['location']
            latitude = location['lat']
            longitude = location['lng']
            print(f"Address: {address} Latitude: {latitude}, Longitude: {longitude}")
            return latitude, longitude
        else:
            print(f"Error: {data['status']}")
            return None, None
    else:
        print(f"HTTP Error: {response.status_code}")
        return None, None

# %%
master_gps_path = 'data/master_gps.csv'

# %%
master_gps_df = pd.read_csv(master_gps_path)

# %%
master_gps_df.shape
# Out:
# (61, 6)

# %%
data = master_gps_df.iloc[47:]

# %%
location_lis = data['LOCATION'].to_list()

# %%
location_lis
# Out:
# ['DELKANDA',
#  'ASIRI CENTRAL',
#  'ASIRI KANDY',
#  'KURUNEGALA',
#  'KOTTAWA',
#  'NEGOMBO',
#  'NAWALA',
#  'MOUNT - LAVINIA',
#  'MALABE',
#  'CR FC',
#  'THALAWATHUGODA',
#  'KANDANA',
#  'KANDY - MCC',
#  'WATTALA']

# %%
address_lis = []
for loc in location_lis:
    # address = loc.split(' ')[0] + ', '+'Sri Lanka'
    address = loc + ', '+'Sri Lanka'
    address_lis.append(address)

# %%
lat_list = []
lon_list = []
for addr in address_lis:
    try:
        print(f'Processing row {addr}')
        lat, lon = get_gcp_gps(addr)
        lat_list.append(lat)
        lon_list.append(lon)
    except Exception as e:
        print(f'Error processing row {addr}: {str(e)}')
        lat_list.append(None)
        lon_list.append(None)
# Out:
# Processing row DELKANDA, Sri Lanka
# Address: DELKANDA, Sri Lanka Latitude: 7.327277, Longitude: 80.6382627
# Processing row ASIRI CENTRAL, Sri Lanka
# Address: ASIRI CENTRAL, Sri Lanka Latitude: 6.9205009, Longitude: 79.86582109999999
# Processing row ASIRI KANDY, Sri Lanka
# Address: ASIRI KANDY, Sri Lanka Latitude: 7.2744094, Longitude: 80.6111499
# Processing row KURUNEGALA, Sri Lanka
# Address: KURUNEGALA, Sri Lanka Latitude: 7.4817695, Longitude: 80.3608876
# Processing row KOTTAWA, Sri Lanka
# Address: KOTTAWA, Sri Lanka Latitude: 6.8411652, Longitude: 79.9654324
# Processing row NEGOMBO, Sri Lanka
# Address: NEGOMBO, Sri Lanka Latitude: 7.205520799999999, Longitude: 79.8512562
# Processing row NAWALA, Sri Lanka
# Address: NAWALA, Sri Lanka Latitude: 6.896419099999999, Longitude: 79.8884819
# Processing row MOUNT - LAVINIA, Sri Lanka
# Address: MOUNT - LAVINIA, Sri Lanka Latitude: 6.830118499999999, Longitude: 79.8800832
# Processing row MALABE, Sri Lanka
# ...

# %%
master_gps_df.columns
# Out:
# Index(['CODE', 'LOCATION', 'ADDRESS', 'LATITUDE', 'LONGITUDE', 'BRAND'], dtype='object')

# %%
existing_gps_df = master_gps_df.iloc[:47]

# %%
existing_address_lis = existing_gps_df['ADDRESS'].to_list()
ex_lat_list = existing_gps_df['LATITUDE'].to_list()
ex_lon_list = existing_gps_df['LONGITUDE'].to_list()

# %%
master_gps_df['ADDRESS'] = existing_address_lis+address_lis
master_gps_df['LATITUDE'] = ex_lat_list+lat_list
master_gps_df['LONGITUDE'] = ex_lon_list+lon_list

# %%
master_gps_df['BRAND'] = 'Arpico'

# %%
master_gps_df.to_csv('data/master_gps_1.csv', index=False)

# %% [markdown]
# ### Cargils update

# %%
import pandas as pd
import requests

# %%
demand_data_df = pd.read_csv('data/more.csv')
master_address_df = pd.read_csv('data/data_gps.csv')

# %%
demand_data_df.shape , master_address_df.shape
# Out:
# ((23, 1), (564, 5))

# %%
car_index = []
car_location = []
car_address = []
for val in (demand_data_df['Data'].values):
    ind = val.split(' ')[0]
    loc_lis = val.split(' ')[1:-5] 
    """append location from values in side loc_lis as string with space"""
    loc = " ".join(loc_lis)
    car_index.append(ind)
    car_location.append(loc)
    add = " ".join(loc_lis[1:]) + ", Cargills Food City, " + "Sri Lanka"
    add = ''.join([i for i in add if not i.isdigit()])
    car_address.append(add)

# %%
len(car_index)
# Out:
# 23

# %%
car_gps_data = pd.DataFrame(columns=['CODE', 'LOCATION', 'ADDRESS', 'LATITUDE', 'LONGITUDE', 'BRAND'])

# %%
car_gps_data['CODE'] = car_index
car_gps_data['LOCATION'] = car_location
car_gps_data['ADDRESS'] = car_address
car_gps_data['BRAND'] = 'Cargills'

# %%
lat_list = []
lon_list = []
for addr in car_address:
    try:
        print(f'Processing row {addr}')
        lat, lon = get_gcp_gps(addr)
        lat_list.append(lat)
        lon_list.append(lon)
    except Exception as e:
        print(f'Error processing row {addr}: {str(e)}')
        lat_list.append(None)
        lon_list.append(None)
# Out:
# Processing row ATTIDIYA, Cargills Food City, Sri Lanka
# Address: ATTIDIYA, Cargills Food City, Sri Lanka Latitude: 7.873053999999999, Longitude: 80.77179699999999
# Processing row BANDARAWELA , Cargills Food City, Sri Lanka
# Address: BANDARAWELA , Cargills Food City, Sri Lanka Latitude: 6.8298077, Longitude: 80.9941178
# Processing row HAVELOCK CITY, Cargills Food City, Sri Lanka
# Address: HAVELOCK CITY, Cargills Food City, Sri Lanka Latitude: 6.8827383, Longitude: 79.8683695
# Processing row WALPOLA, Cargills Food City, Sri Lanka
# Address: WALPOLA, Cargills Food City, Sri Lanka Latitude: 6.919566, Longitude: 79.9269549
# Processing row LEWELLA, Cargills Food City, Sri Lanka
# Address: LEWELLA, Cargills Food City, Sri Lanka Latitude: 7.2989123, Longitude: 80.65067669999999
# Processing row ANGUNAKOLAPELASSA, Cargills Food City, Sri Lanka
# Address: ANGUNAKOLAPELASSA, Cargills Food City, Sri Lanka Latitude: 6.165568899999999, Longitude: 80.9031172
# ...

# %%
car_gps_data['LATITUDE'] = lat_list
car_gps_data['LONGITUDE'] = lon_list

# %%
car_gps_data.to_csv('data/07-03-2025-PO.csv', index=False)

# %%
# car_index = demand_data_df['CODE'].to_list()

# %%
# order_ids_str = list(map(str, car_index))

# # Filter the dataframe
# sub_df = master_address_df[master_address_df['CODE'].isin(order_ids_str)]

# %%
# sub_df.reset_index(inplace=True, drop=True)

# %%
# sub_df

# %%
# address_cargils = []

# for addr in sub_df['ADDRESS'].to_list():
#     if len(addr.split(','))>2:  
#         new_add = addr.split(',')[-2:]
#     elif len(addr.split(','))==1:
#         new_add = addr.split(',')
#     else:
#         new_add = addr.split(',')[1:]
#     new_add = "Cargills Food City - " + ','.join(new_add).strip(' ').strip('.') + ',Sri Lanka'
#     address_cargils.append(new_add)

# %%
# address_cargils

# %%
# address_cargils = []

# for addr in sub_df['ADDRESS'].to_list():
#     address_cargils.append(addr)

# %%
import time

# %%
# lat_list = []
# lon_list = []
# for addr in address_cargils:
#     try:
#         print(f'Processing row {addr}')
#         lat, lon = get_gcp_gps(addr)
#         time.sleep(0.0001)
#         lat_list.append(lat)
#         lon_list.append(lon)
#     except Exception as e:
#         print(f'Error processing row {addr}: {str(e)}')
#         lat_list.append(None)
#         lon_list.append(None)

# %%
# sub_df['LATITUDE'] = lat_list
# sub_df['LONGITUDE'] = lon_list
# sub_df['BRAND'] = 'Cargills'

# %%
# sub_df.to_csv('data/03-Mar-2025-in-4.csv', index=False)

# %%
# not_code = []
# for ind in order_ids_str:
#     if ind not in sub_df['CODE'].values:
#         not_code.append(ind)

# %%
# len(not_code)
# Out:
# 78

# %%
# # Filter the dataframe
# sub_df_no = demand_data_df[demand_data_df['CODE'].astype(str).isin(not_code)]
# sub_df_no.to_csv('data/03-Mar-2025-No.csv', index=False)

# %%
# no_locations = []
# no_address = []
# for code in not_code:
#     ind = car_index.index(code)
#     no_locations.append(car_location[ind])
#     no_address.append(car_address[ind])

# %% [markdown]
# ### Keels

# %%
keels_df = pd.read_csv('data/matched_outlet_Keells PO 03.03.2025.csv')
master_address_df = pd.read_csv('data/data_gps.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[228], line 1
# ----> 1 keels_df = pd.read_csv('data/matched_outlet_Keells PO 03.03.2025.csv')
#       2 master_address_df = pd.read_csv('data/data_gps.csv')
#
# ...

# %%
keels_df.shape
# Out:
# (151, 2)

# %%
k_ind = keels_df['Code'].to_list()

# %%
keels_df = keels_df.drop_duplicates(subset=['Code'])

# %%
keels_sub_df = master_address_df[master_address_df['CODE'].isin(k_ind)]

# %%
keels_sub_df.to_csv('data/keels.csv', index=False)

# %%
keels_address_lis = keels_sub_df['ADDRESS'].to_list()

# %%
keels_address = []
for add in keels_address_lis:
    new_add = add.split(',')[1:]
    new_add = ', '.join(new_add) + ', Sri Lanka'
    keels_address.append(new_add)

# %%
lat_list = []
lon_list = []
for addr in keels_address:
    try:
        print(f'Processing row {addr}')
        lat, lon = get_gcp_gps(addr)
        lat_list.append(lat)
        lon_list.append(lon)
    except Exception as e:
        print(f'Error processing row {addr}: {str(e)}')
        lat_list.append(None)
        lon_list.append(None)
# Out:
# Processing row  Malambe Road,  Athurugiriya, Sri Lanka
# Address:  Malambe Road,  Athurugiriya, Sri Lanka Latitude: 6.8723185, Longitude: 80.0003875
# Processing row  Malabe Road,  Arangala,  Athurugiriya, Sri Lanka
# Address:  Malabe Road,  Arangala,  Athurugiriya, Sri Lanka Latitude: 6.886079899999999, Longitude: 79.9626354
# Processing row  Kesbewa Road,  Katuwala,  Boralasgomuwa, Sri Lanka
# Address:  Kesbewa Road,  Katuwala,  Boralasgomuwa, Sri Lanka Latitude: 6.8525143, Longitude: 79.8976618
# Processing row  Crescat Boulevard,  Galle Road,  Colombo 03, Sri Lanka
# Address:  Crescat Boulevard,  Galle Road,  Colombo 03, Sri Lanka Latitude: 6.917104399999999, Longitude: 79.84818709999999
# Processing row  Capital Mall,  Madiwela Road,  Thalawathugoda, Sri Lanka
# Address:  Capital Mall,  Madiwela Road,  Thalawathugoda, Sri Lanka Latitude: 6.8733711, Longitude: 79.9171546
# Processing row  Sir D.B. Jayathilake Mawatha,  (Hill Street),  Dehiwala, Sri Lanka
# ...

# %%
keels_sub_df['LATITUDE'] = lat_list
keels_sub_df['LONGITUDE'] = lon_list
keels_sub_df['BRAND'] = "Keels"

# %%
keels_sub_df.to_csv('data/keels.csv', index=False)

# %%
import folium
import pandas as pd

def visualize_all_locations(csv_file_path):
    """
    Visualize all locations from a CSV file on a folium map.
    :param csv_file_path: Path to the CSV file containing location data
    :return: folium.Map object
    """
    # Load the CSV data into a DataFrame
    try:
        df = pd.read_csv(csv_file_path)
        df = df.iloc[200:220]
    except Exception as e:
        print(f"Error loading CSV file {csv_file_path}: {e}")
        return None

    # Create a map centered at the mean of all latitudes and longitudes
    map_center = [df['LATITUDE'].mean(), df['LONGITUDE'].mean()]
    m = folium.Map(location=map_center, zoom_start=10)

    # Add a marker for each location
    for _, row in df.iterrows():
        folium.Marker(
            location=[row['LATITUDE'], row['LONGITUDE']],
            popup=f"CODE: {row['CODE']}<br>LOCATION: {row['LOCATION']}<br>ADDRESS: {row['ADDRESS']}<br>BRAND: {row['BRAND']}",
            icon=folium.Icon(color='blue', icon='info-sign')
        ).add_to(m)

    # Add title
    title_html = '<h3 align="center" style="font-size:16px">All Locations Map</h3>'
    m.get_root().html.add_child(folium.Element(title_html))

    return m

# Example usage
if __name__ == "__main__":
    csv_file_path = 'data/master_gps-2.csv' # Adjust path to your CSV file
    map_obj = visualize_all_locations(csv_file_path)
    # Open 'all_locations_map.html' in a browser to view the map

# %%
map_obj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
