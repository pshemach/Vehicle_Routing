# %%
po_path = '../data/test/orders/03-03-2025-PO.csv'

# %%
import pandas as pd

# %%
df = pd.read_csv(po_path)

# %%
df.columns
# Out:
# Index(['CODE', 'SALE', 'LOCATION', 'ADDRESS', 'LATITUDE', 'LONGITUDE', 'BRAND',
#        'DISTRICT', 'DATE'],
#       dtype='object')

# %%
df['SALE'] = df['SALE'].str.replace(',', '', regex=False).astype(float)

# %%
df['SALE'].sum()
# Out:
# 9861728.09
