# %%
import pandas as pd
import requests
import time

def get_district(lat, lon, api_key):
    """Reverse geocode to get the district using Google Maps API."""
    url = f"https://maps.googleapis.com/maps/api/geocode/json?latlng={lat},{lon}&key={api_key}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if data['status'] == 'OK':
            for component in data['results'][0]['address_components']:
                if 'administrative_area_level_2' in component['types']:
                    return component['long_name']
    return None

def add_district_column(df, api_key, sleep_time=0.1):
    """Add a new 'District' column to the dataframe using reverse geocoding."""
    districts = []
    for _, row in df.iterrows():
        district = get_district(row['LATITUDE'], row['LONGITUDE'], api_key)
        districts.append(district)
        time.sleep(sleep_time)  # To avoid exceeding rate limits
    df['District'] = districts
    return df

# Example usage:
df = pd.read_csv("../data/master/master_gps.csv")  # Replace with your actual file
api_key = 'AIzaSyACpYMHnmkd8DWxWS3KTJ70EeKIRYN2xHM'
df_with_districts = add_district_column(df, api_key)

# %%
df_with_districts
# Out:
#      CODE               LOCATION  \
# 0       3             Wattala SC
# 1       4       Borelasgamuwa SS
# 2       5           Hyde Park SC
# 3      10             Nawinna SC
# 4     105              Matara SC
# ..    ...                    ...
# 645  1881             EX ATIGALA
# 646  1883          EX KUMBALGAMA
# 647  1884            EX KONDAVIL
# 648  1886     EX CAPITAL HEIGHTS
# 649  1889  EX WORLD TRADE CENTRE
#
#                                                ADDRESS  LATITUDE  LONGITUDE  \
# 0                                   Wattala, Sri Lanka  6.990668  79.893171
# 1                             Borelasgamuwa, Sri Lanka  6.840989  79.901719
# 2                                      Hyde, Sri Lanka  6.917587  79.858519
# 3                                   Nawinna, Sri Lanka  6.853331  79.915072
# 4                                    Matara, Sri Lanka  5.949631  80.546853
# ..                                                 ...       ...        ...
# 645             ATIGALA, Cargills Food City, Sri Lanka  6.894662  80.056286
# 646          KUMBALGAMA, Cargills Food City, Sri Lanka  6.689882  80.804557
# 647            KONDAVIL, Cargills Food City, Sri Lanka  9.702180  80.035403
# 648     CAPITAL HEIGHTS, Cargills Food City, Sri Lanka  6.909579  79.900502
# 649  WORLD TRADE CENTRE, Cargills Food City, Sri Lanka  6.932674  79.841364
#
#         BRAND   District
# 0      Arpico    Gampaha
# 1      Arpico    Colombo
# 2      Arpico    Colombo
# 3      Arpico    Colombo
# 4      Arpico     Matara
# ..        ...        ...
# 645  Cargills    Colombo
# 646  Cargills  Ratnapura
# 647  Cargills     Jaffna
# 648  Cargills    Colombo
# 649  Cargills    Colombo
#
# [650 rows x 7 columns]

# %%
# Preview and save
print(df_with_districts[['CODE', 'LOCATION', 'District']].head())
df_with_districts.to_csv("output_with_districts.csv", index=False)
# Out:
#   CODE          LOCATION District
# 0    3        Wattala SC  Gampaha
# 1    4  Borelasgamuwa SS  Colombo
# 2    5      Hyde Park SC  Colombo
# 3   10        Nawinna SC  Colombo
# 4  105         Matara SC   Matara
