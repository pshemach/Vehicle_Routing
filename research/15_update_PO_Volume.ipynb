# %%
import pandas as pd
# Out:
# Running cells with 'venv (Python 3.11.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/HP/OneDrive - University of Moratuwa/Desktop/E-Vision-Projects/TMS_Project/TMS-Backend/venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
day = '07'

# %%
po_pre = f'../data/test/{day}-03-2025-PO.csv'
po_vol = f'../data/test/po-volume/{day}-03-2025-PO.csv'

# %%
pre_df = pd.read_csv(po_pre)
vol_df = pd.read_csv(po_vol)

# %%
pre_df.shape
# Out:
# (23, 2)

# %%
vol_df.shape
# Out:
# (18, 3)

# %%
codes_not_in_vol = pre_df[~pre_df['CODE'].isin(vol_df['CODE'])]['CODE'].unique()

# %%
codes_not_in_vol
# Out:
# array([1585, 1689, 1691, 1693, 1873], dtype=int64)

# %%
codes_not_in_vol_df = pre_df[~pre_df['CODE'].isin(vol_df['CODE'])]

# %%
# codes_not_in_vol_df.to_csv(f'../data/test/{day}-03-2025-PO-MISSING.csv', index=False)

# %%
po_path = f'../data/test/orders/{day}-03-2025-PO.csv'

# %%
po_df = pd.read_csv(po_path)

# %%
po_df = po_df.merge(vol_df[['CODE', 'VOLUME']], on='CODE', how='left')

# %%
mn =  vol_df['VOLUME'].mean()

# %%
mn
# Out:
# 169816.18000000002

# %%
po_df['VOLUME'] = po_df['VOLUME'].fillna(mn)

# %%
po_df.shape
# Out:
# (23, 10)

# %%
po_df.to_csv(f'../data/test/orders-vol/{day}-03-2025-PO.csv', index=False)

# %%
lis = ['s','b']

lis.index('b')
# Out:
# 1

# %%
veh_lis = [{"vehicleId": "V041", "vehicleName": "Truck 01", "fleetName": "Standard Fleet", "vehicleType": "Truck", "maxWeight": "5000", "maxVolume": "90", "timeWindow": "08:00-18:00", "maxDistance": "200", "maxVisits": "12"}, {"vehicleId": "V233", "vehicleName": "Truck 02", "fleetName": "Standard Fleet", "vehicleType": "Truck", "maxWeight": "5000", "maxVolume": "90", "timeWindow": "08:00-18:00", "maxDistance": "200", "maxVisits": "12"}, {"vehicleId": "V864", "vehicleName": "Truck 03", "fleetName": "Standard Fleet", "vehicleType": "Truck", "maxWeight": "5000", "maxVolume": "90", "timeWindow": "08:00-18:00", "maxDistance": "200", "maxVisits": "12"}, {"vehicleId": "V647", "vehicleName": "Truck 04", "fleetName": "Standard Fleet", "vehicleType": "Truck", "maxWeight": "5000", "maxVolume": "90", "timeWindow": "08:00-18:00", "maxDistance": "200", "maxVisits": "12"}, {"vehicleId": "V041", "vehicleName": "Truck 01", "fleetName": "Standard Fleet", "vehicleType": "Truck", "maxWeight": "5000", "maxVolume": "90", "timeWindow": "08:00-18:00", "maxDistance": "200", "maxVisits": "12"}, {"vehicleId": "V233", "vehicleName": "Truck 02", "fleetName": "Standard Fleet", "vehicleType": "Truck", "maxWeight": "5000", "maxVolume": "90", "timeWindow": "08:00-18:00", "maxDistance": "200", "maxVisits": "12"}, {"vehicleId": "V864", "vehicleName": "Truck 03", "fleetName": "Standard Fleet", "vehicleType": "Truck", "maxWeight": "5000", "maxVolume": "90", "timeWindow": "08:00-18:00", "maxDistance": "200", "maxVisits": "12"}, {"vehicleId": "V647", "vehicleName": "Truck 04", "fleetName": "Standard Fleet", "vehicleType": "Truck", "maxWeight": "5000", "maxVolume": "90", "timeWindow": "08:00-18:00", "maxDistance": "200", "maxVisits": "12"}, {"vehicleId": "V843", "vehicleName": "Truck 05", "fleetName": "Standard Fleet", "vehicleType": "Truck", "maxWeight": "5000", "maxVolume": "90", "timeWindow": "08:00-18:00", "maxDistance": "200", "maxVisits": "12"}]

# %%
from datetime import datetime, timedelta

# %%
vehicleId_lis = []
vehicleName_lis = []
fleetName_lis = []
maxVolume_lis = []
timeWindow_lis = []
maxDistance_lis = []
maxVisits_lis = []
for v in veh_lis:
    time_lis = v['timeWindow'].split('-')
    start, end = time_lis[0], time_lis[1]
    start_time = datetime.strptime(start, "%H:%M")
    end_time = datetime.strptime(end, "%H:%M")
    # Calculate the difference
    time_diff = end_time - start_time
    # Convert to hours and minutes
    total_hours = time_diff.total_seconds() / 3600
    print(total_hours)
# Out:
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
# 10.0
